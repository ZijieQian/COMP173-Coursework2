# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import PIL
from PIL import Image
import pathlib
import os
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.losses import *
import requests
# !pip install pyunpack patool
import pyunpack
import matplotlib.pyplot as plt
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint
import sys
from tensorflow.keras.optimizers import Adam
# !pip install rarfile segmentation-models git+https://github.com/davej23/image-segmentation-keras.git rioxarray
from rarfile import RarFile
import segmentation_models as sm
from keras.applications import vgg16
from sklearn.metrics import *
import rioxarray as rxr
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
import PIL.Image
import math
# Out:
# 2025-12-10 04:17:28.811763: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-10 04:17:29.010274: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-10 04:17:29.057098: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-12-10 04:17:29.873311: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-12-10 04:17:29.873388: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-12-10 04:17:29.873396: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Segmentation Models: using `keras` framework.

# %% [markdown]
# # Functions

# %%
'''
  Returns an image plot of mask prediction
'''

def reconstruct_image(model, image, rounded=False):

  # Find model prediction
  reconstruction = model.predict(image).reshape(image.shape[1], image.shape[2])
  # Standardise between 0-1
  reconstruction = reconstruction/np.max(reconstruction)

  # Round to 0-1, binary pixel-by-pixel classification 
  if rounded:
    reconstruction = np.round(reconstruction)

  # Plot reconstructed mask (prediction)
  plt.imshow(reconstruction)

# %%
'''
  Returns array of mask prediction, given model and image
'''
def reconstruct_array(model, image, rounded=False):

  # Find model prediction
  reconstruction = model.predict(image).reshape(image.shape[1], image.shape[2])

  if rounded:
    reconstruction = np.round(reconstruction)

  return reconstruction # Returns array

# %%
'''
  Metric functions for evaluation
'''
def iou_metric(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)  # 二值化

    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection

    return (intersection + smooth) / (union + smooth)

def score_eval(model, image, mask): # Gives score of mask vs prediction
  if type(image) != list:   
    reconstruction = model.predict(image).reshape(mask.shape[1], mask.shape[2])
    reconstruction = np.round(reconstruction).flatten()

    return accuracy_score(mask.flatten(), reconstruction)

  else: # If a list of images input, find accuracy for each
    scores = []
    for i in range(len(image)):
      reconstruction = model.predict(image[i].reshape(1, 512, 512, 3))
      reconstruction = np.round(reconstruction).flatten()

      scores.append(accuracy_score(mask[i].flatten(), reconstruction))

    return scores


def recall_eval(model, image, mask): # Find recall score
  if type(image) != list:   
    reconstruction = model.predict(image).reshape(mask.shape[1], mask.shape[2])
    reconstruction = np.round(reconstruction).flatten()

    return recall_score(mask.flatten(), reconstruction, average='weighted')

  else: # If a list of images input, find accuracy for each
    recall = []
    for i in range(len(image)):
        reconstruction = model.predict(image[i]).reshape(mask[i].shape[1], mask[i].shape[2])
        reconstruction = np.round(reconstruction).flatten()

        recall.append(recall_score(mask[i].flatten(), reconstruction, average='weighted'))

    return recall

def precision_eval(model, image, mask): # Find precision score
  if type(image) != list:   
    reconstruction = model.predict(image).reshape(mask.shape[1], mask.shape[2])
    reconstruction = np.round(reconstruction).flatten()

    return precision_score(mask.flatten(), reconstruction, average='weighted')

  else: # If a list of images input, find accuracy for each
    precision = []
    for i in range(len(image)):
        reconstruction = model.predict(image[i]).reshape(mask[i].shape[1], mask[i].shape[2])
        reconstruction = np.round(reconstruction).flatten()

        precision.append(precision_score(mask[i].flatten(), reconstruction, average='weighted'))

    return precision

def f1_score_eval(model, image, mask): # Find F1-score
    prec = np.mean(precision_eval(model, image, mask))
    rec = np.mean(recall_eval(model, image, mask))

    if prec + rec == 0:
        return 0

    return 2 * (prec * rec) / (prec + rec)

def f1_score_eval_basic(precision, recall):
    prec = np.mean(precision)
    rec = np.mean(recall)

    if prec + rec == 0:
        return 0

    return 2 * (prec * rec) / (prec + rec)

def produce_mask(image): # Outputs rounded image (binary)
  return np.round(image)

# %% [markdown]
# # Ingest and Process New Dataset

# %%
base_dir = r"./Nepal landslide dataset/"

# %%
# Ingest images

training_images_list = os.listdir(r"{}Training/image/".format(base_dir))
training_masks_list = []
training_images = []

for n in training_images_list:
    im = PIL.Image.open(r"{}Training/image/{}".format(base_dir, n))
    training_images.append(im)
    # Nepal uses .tiff → label uses .png
    training_masks_list.append(n[:-5] + '.png')

# Training masks
training_masks = []
for n in training_masks_list:
    im = PIL.Image.open(r"{}Training/label/{}".format(base_dir, n))
    training_masks.append(im)

# -------------------------
# Test images
# -------------------------
test_images_list = os.listdir(r"{}Test/image/".format(base_dir))
test_images = []

for n in test_images_list:
    im = PIL.Image.open(r"{}Test/image/{}".format(base_dir, n))
    test_images.append(im)

# -------------------------
# Validation images
# -------------------------
validation_images_list = os.listdir(r"{}Validation/images/".format(base_dir))
validation_masks_list = []
validation_images = []

for n in validation_images_list:
    im = PIL.Image.open(r"{}Validation/images/{}".format(base_dir, n))
    validation_images.append(im)
    validation_masks_list.append(n[:-5] + '.png')

# Validation masks
validation_masks = []
for n in validation_masks_list:
    im = PIL.Image.open(r"{}Validation/masks/{}".format(base_dir, n))
    validation_masks.append(im)

# %%
# Pre-process (same as original, only ensure resize)
# -------------------------

# images (3-channel)
for i in range(len(training_images)):
    arr = np.array(training_images[i]) / 255
    arr = cv2.resize(arr, (512, 512))     
    arr = arr.reshape(1, 512, 512, 3)
    training_images[i] = arr.astype('float32')

# masks (1-channel)
for i in range(len(training_masks)):
    arr = np.array(training_masks[i])
    arr = cv2.resize(arr, (512, 512))    
    arr = arr.reshape(1, 512, 512, 1)
    training_masks[i] = arr.astype('int')

# validation images
for i in range(len(validation_images)):
    arr = np.array(validation_images[i]) / 255
    arr = cv2.resize(arr, (512, 512))
    arr = arr.reshape(1, 512, 512, 3)
    validation_images[i] = arr.astype('float32')

# validation masks
for i in range(len(validation_masks)):
    arr = np.array(validation_masks[i])
    arr = cv2.resize(arr, (512, 512))
    arr = arr.reshape(1, 512, 512, 1)
    validation_masks[i] = arr.astype('int')

# test images
for i in range(len(test_images)):
    arr = np.array(test_images[i]) / 255
    arr = cv2.resize(arr, (512, 512))
    arr = arr.reshape(1, 512, 512, 3)
    test_images[i] = arr.astype('float32')

# %%
validation_Nepal_landslide_dataset = tf.data.Dataset.from_tensor_slices((validation_images, validation_masks))
# Out:
# 2025-12-10 04:17:33.024446: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-10 04:17:33.798158: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22168 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:56:00.0, compute capability: 8.6

# %%
# Data loader/generator from: https://github.com/bragagnololu/UNet-defmapping.git
#

def adjustData(img, mask, num_class):
  
    mask[mask > 0.3] = 1 # FOREST
    mask[mask <= 0.3] = 0 # NON-FOREST

    return (img,mask)

def trainGenerator(batch_size,
                   image_array,
                   mask_array,
                   aug_dict,
                   image_save_prefix  = "image",
                   mask_save_prefix  = "mask",
                   num_class = 2,
                   save_to_dir = None,
                   target_size = (512,512),
                   seed = 1):

    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)

    image_generator = image_datagen.flow(image_array,
                                           batch_size = batch_size,
                                           save_to_dir = save_to_dir,
                                           save_prefix = image_save_prefix,
                                           seed = seed) 

    mask_generator = mask_datagen.flow(mask_array,
                                           batch_size = batch_size,
                                           save_to_dir = save_to_dir,
                                           save_prefix = mask_save_prefix,
                                           seed = seed)
    
    train_generator = zip(image_generator, mask_generator)
    
    for (img,mask) in train_generator: 
        img, mask = adjustData(img, mask, num_class)
        yield (img, mask)

# %%
t_images = np.stack(training_images)
t_masks = np.stack(training_masks)
t_images = np.squeeze(t_images, axis=1)
t_masks  = np.squeeze(t_masks, axis=1)

v_images = np.stack(validation_images)
v_masks = np.stack(validation_masks)

data_gen_args = dict(
    rotation_range=10,
    width_shift_range=0.05,
    height_shift_range=0.05,
    zoom_range=0.05,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='reflect',
)

train = trainGenerator(1, t_images, t_masks, data_gen_args, save_to_dir=None)

# positive_indices = [i for i in range(len(t_masks)) if np.sum(t_masks[i]) > 0]

# positive_images = t_images[positive_indices]
# positive_masks = t_masks[positive_indices]

# # 2. 设定 oversample 倍数
# REPEAT = 25   # <--- 小目标推荐 20-30

# # 3. 拼接新数组（原数据 + positive 数据重复）
# t_images_aug = np.concatenate(
#     [t_images] + [positive_images] * REPEAT,
#     axis=0
# )

# t_masks_aug = np.concatenate(
#     [t_masks] + [positive_masks] * REPEAT,
#     axis=0
# )

# # 4. 打乱顺序
# indices = np.arange(len(t_images_aug))
# np.random.shuffle(indices)

# t_images_aug = t_images_aug[indices]
# t_masks_aug  = t_masks_aug[indices]


# train = trainGenerator(1, t_images_aug, t_masks_aug, data_gen_args, None)

# # # 6. 计算 steps per epoch
# batch_size = 1
# steps_per_epoch = len(t_images_aug) // batch_size

# %%
BETA = 0.95
SMOOTH_TERM = 1e-7

def dice_coef(y_true, y_pred, smooth=SMOOTH_TERM):
    y_true_float = K.cast(y_true, 'float32') 
    
    y_true_f = K.flatten(y_true_float)
    y_pred_f = K.flatten(y_pred)
    
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

def weighted_bce_loss(y_true, y_pred, beta=BETA):
    # 🌟 关键步骤：使用 K.cast() 将输入的 y_true (int64) 转换为 float32
    y_true_float = K.cast(y_true, 'float32') 

    # 计算标准的二元交叉熵
    bce = K.binary_crossentropy(y_true_float, y_pred)
    
    # 权重计算
    # weight = beta * y_true_float + (1 - beta) * (1 - y_true_float)
    # 当 y_true=1 (前景) 时，weight=beta
    # 当 y_true=0 (背景) 时，weight=1-beta
    
    # K.sum(y_true_float) 是前景像素总数
    # K.sum(1 - y_true_float) 是背景像素总数
    
    # 计算每个像素的权重：前景像素权重为 beta，背景像素权重为 1-beta
    weight = beta * y_true_float + (1.0 - beta) * (1.0 - y_true_float)
    
    # 对加权后的 BCE 求平均
    weighted_bce = weight * bce
    return K.mean(weighted_bce)

def bce_dice_loss_weighted(y_true, y_pred):
    # 1. 加权 BCE
    wbce = weighted_bce_loss(y_true, y_pred)
    
    # 2. Dice Loss (使用 y_true_float 和调整后的平滑项)
    dice = dice_loss(y_true, y_pred)
    
    # 结合两种损失
    return 0.5*wbce + 0.5*dice

    
def tversky_loss(y_true, y_pred, alpha=0.7, beta=0.3):
    y_true_pos = K.flatten(y_true)
    y_pred_pos = K.flatten(y_pred)
    true_pos = K.sum(y_true_pos * y_pred_pos)
    false_neg = K.sum(y_true_pos * (1-y_pred_pos))
    false_pos = K.sum((1-y_true_pos) * y_pred_pos)
    return 1 - (true_pos + 1e-6) / (true_pos + alpha*false_neg + beta*false_pos + 1e-6)

def tversky_dice_loss_weighted(y_true, y_pred):
    # 1. 加权 BCE
    tversky = tversky_loss(y_true, y_pred)
    
    # 2. Dice Loss (使用 y_true_float 和调整后的平滑项)
    dice = dice_loss(y_true, y_pred)
    
    # 结合两种损失
    return 0.7*tversky + 0.3*dice

# import numpy as np

# def mask_stats(masks):
#     # masks: numpy array (N,H,W,1) or list
#     a = np.array(masks)
#     if a.ndim==4 and a.shape[-1]==1:
#         a = a[...,0]
#     flat = a.flatten()
#     unique, counts = np.unique(flat, return_counts=True)
#     freq = dict(zip(unique.tolist(), counts.tolist()))
#     total = flat.size
#     print("unique values & counts:", freq)
#     print("total pixels:", total)
#     for k,v in freq.items():
#         print(f"value {k}: {v} pixels, ratio {v/total:.6f}")
#     return freq

# mask_stats(t_masks)   # 把你训练集的 mask 数组代入
# mask_stats(validation_masks)

# %%
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.callbacks import ReduceLROnPlateau
# class CosineAnnealingScheduler(Callback):
#     def __init__(self, T_max, eta_min=1e-6, verbose=1):
#         super().__init__()
#         self.T_max = T_max
#         self.eta_min = eta_min
#         self.verbose = verbose

#     def on_epoch_begin(self, epoch, logs=None):
#         lr_max = 1e-3
#         lr = self.eta_min + (lr_max - self.eta_min) * (
#             1 + math.cos(math.pi * epoch / self.T_max)) / 2
        
#         tf.keras.backend.set_value(self.model.optimizer.lr, lr)
#         if self.verbose:
#             print(f"Epoch {epoch+1}: LR = {lr}")
# scheduler = CosineAnnealingScheduler(T_max=50, eta_min=1e-6)

# optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)

reduce_lr = ReduceLROnPlateau(
    monitor='val_iou_metric',  # 你的 IoU 指标名字
    mode='max',                # IoU 越大越好
    factor=0.5,
    patience=7,
    verbose=1,
    min_lr=1e-7
)

# %% [markdown]
# # Models

# %% [markdown]
# ## U-Net

# %%
'''
  Convolutional block with set parameters and activation layer after
'''

def convBlock(input, filters, kernel, kernel_init='he_normal', act='relu', transpose=False):
  if transpose == False:
    #conv = ZeroPadding2D((1,1))(input)
    conv = Conv2D(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)
  else:
    #conv = ZeroPadding2D((1,1))(input)
    conv = Conv2DTranspose(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)

  conv = Activation(act)(conv)
  return conv
  
'''
  U-Net model
'''

def UNet(trained_weights = None, input_size = (512,512,3), drop_rate = 0.25, lr=0.0001):

    ## Can add pretrained weights by specifying 'trained_weights'

    # Input layer
    inputs = Input(input_size, batch_size=1)

    ## Contraction phase
    conv1 = convBlock(inputs, 64, 3)
    conv1 = convBlock(conv1, 64, 3)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = convBlock(pool1, 128, 3)
    conv2 = convBlock(conv2, 128, 3)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    #drop2 = Dropout(drop_rate)(pool2)

    conv3 = convBlock(pool2, 256, 3)
    conv3 = convBlock(conv3, 256, 3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    #drop3 = Dropout(drop_rate)(pool3)

    conv4 = convBlock(pool3, 512, 3)
    conv4 = convBlock(conv4, 512, 3)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    #drop4 = Dropout(drop_rate)(pool4)

    conv5 = convBlock(pool4, 1024, 3)
    conv5 = convBlock(conv5, 1024, 3)

    ## Expansion phase
    up6 = (Conv2DTranspose(512, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv5))
    merge6 = concatenate([conv4,up6])
    conv6 = convBlock(merge6, 512, 3)
    conv6 = convBlock(conv6, 512, 3)
    #conv6 = Dropout(drop_rate)(conv6)

    up7 = (Conv2DTranspose(256, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv6))
    merge7 = concatenate([conv3,up7])
    conv7 = convBlock(merge7, 256, 3)
    conv7 = convBlock(conv7, 256, 3)
    #conv7 = Dropout(drop_rate)(conv7)

    up8 = (Conv2DTranspose(128, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv7))
    merge8 = concatenate([conv2,up8])
    conv8 = convBlock(merge8, 128, 3)
    conv8 = convBlock(conv8, 128, 3)
    #conv8 = Dropout(drop_rate)(conv8)

    up9 = (Conv2DTranspose(64, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv8))
    merge9 = concatenate([conv1,up9])
    conv9 = convBlock(merge9, 64, 3)
    conv9 = convBlock(conv9, 64, 3)

    # Output layer
    conv10 = convBlock(conv9, 1, 1, act='sigmoid')

    model = Model(inputs, conv10)

    # model.compile(optimizer = Adam(learning_rate = lr), loss = 'binary_crossentropy', metrics = ['accuracy', 'mse'])
    model.compile(optimizer = Adam(learning_rate = lr), loss = bce_dice_loss_weighted, metrics = ['accuracy', iou_metric])
    if trained_weights != None:
    	model.load_weights(trained_weights)

    return model

# %%
# Print model layers and number of parameters
UNet().summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(1, 512, 512, 3)]   0           []
#
#  conv2d (Conv2D)                (1, 512, 512, 64)    1792        ['input_1[0][0]']
#
#  activation (Activation)        (1, 512, 512, 64)    0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (1, 512, 512, 64)    36928       ['activation[0][0]']
#
#  activation_1 (Activation)      (1, 512, 512, 64)    0           ['conv2d_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (1, 256, 256, 64)    0           ['activation_1[0][0]']
#
#  conv2d_2 (Conv2D)              (1, 256, 256, 128)   73856       ['max_pooling2d[0][0]']
#
#  activation_2 (Activation)      (1, 256, 256, 128)   0           ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (1, 256, 256, 128)   147584      ['activation_2[0][0]']
#
#  activation_3 (Activation)      (1, 256, 256, 128)   0           ['conv2d_3[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (1, 128, 128, 128)  0           ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (1, 128, 128, 256)   295168      ['max_pooling2d_1[0][0]']
#
#  activation_4 (Activation)      (1, 128, 128, 256)   0           ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (1, 128, 128, 256)   590080      ['activation_4[0][0]']
#
#  activation_5 (Activation)      (1, 128, 128, 256)   0           ['conv2d_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (1, 64, 64, 256)    0           ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (1, 64, 64, 512)     1180160     ['max_pooling2d_2[0][0]']
#
#  activation_6 (Activation)      (1, 64, 64, 512)     0           ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (1, 64, 64, 512)     2359808     ['activation_6[0][0]']
#
#  activation_7 (Activation)      (1, 64, 64, 512)     0           ['conv2d_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (1, 32, 32, 512)    0           ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (1, 32, 32, 1024)    4719616     ['max_pooling2d_3[0][0]']
#
#  activation_8 (Activation)      (1, 32, 32, 1024)    0           ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (1, 32, 32, 1024)    9438208     ['activation_8[0][0]']
#
#  activation_9 (Activation)      (1, 32, 32, 1024)    0           ['conv2d_9[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (1, 64, 64, 512)    2097664     ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (1, 64, 64, 1024)    0           ['activation_7[0][0]',
#                                                                   'conv2d_transpose[0][0]']
#
#  conv2d_10 (Conv2D)             (1, 64, 64, 512)     4719104     ['concatenate[0][0]']
#
#  activation_10 (Activation)     (1, 64, 64, 512)     0           ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (1, 64, 64, 512)     2359808     ['activation_10[0][0]']
#
#  activation_11 (Activation)     (1, 64, 64, 512)     0           ['conv2d_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (1, 128, 128, 256)  524544      ['activation_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (1, 128, 128, 512)   0           ['activation_5[0][0]',
#                                                                   'conv2d_transpose_1[0][0]']
#
#  conv2d_12 (Conv2D)             (1, 128, 128, 256)   1179904     ['concatenate_1[0][0]']
#
#  activation_12 (Activation)     (1, 128, 128, 256)   0           ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (1, 128, 128, 256)   590080      ['activation_12[0][0]']
#
#  activation_13 (Activation)     (1, 128, 128, 256)   0           ['conv2d_13[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (1, 256, 256, 128)  131200      ['activation_13[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (1, 256, 256, 256)   0           ['activation_3[0][0]',
#                                                                   'conv2d_transpose_2[0][0]']
#
#  conv2d_14 (Conv2D)             (1, 256, 256, 128)   295040      ['concatenate_2[0][0]']
#
#  activation_14 (Activation)     (1, 256, 256, 128)   0           ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)             (1, 256, 256, 128)   147584      ['activation_14[0][0]']
#
#  activation_15 (Activation)     (1, 256, 256, 128)   0           ['conv2d_15[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (1, 512, 512, 64)   32832       ['activation_15[0][0]']
#  spose)
#
#  concatenate_3 (Concatenate)    (1, 512, 512, 128)   0           ['activation_1[0][0]',
#                                                                   'conv2d_transpose_3[0][0]']
#
#  conv2d_16 (Conv2D)             (1, 512, 512, 64)    73792       ['concatenate_3[0][0]']
#
#  activation_16 (Activation)     (1, 512, 512, 64)    0           ['conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)             (1, 512, 512, 64)    36928       ['activation_16[0][0]']
#
#  activation_17 (Activation)     (1, 512, 512, 64)    0           ['conv2d_17[0][0]']
#
#  conv2d_18 (Conv2D)             (1, 512, 512, 1)     65          ['activation_17[0][0]']
#
#  activation_18 (Activation)     (1, 512, 512, 1)     0           ['conv2d_18[0][0]']
#
# ==================================================================================================
# Total params: 31,031,745
# Trainable params: 31,031,745
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Attention U-Net

# %%
'''
  Convolutional block with two conv layers and two activation layers
'''

def convBlock2(input, filters, kernel, kernel_init='he_normal', act='relu', transpose=False):
  if transpose == False:
    conv = Conv2D(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)
    conv = Activation(act)(conv)
    conv = Conv2D(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(conv)
    conv = Activation(act)(conv)
  else:
    conv = Conv2DTranspose(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)
    conv = Activation(act)(conv)
    conv = Conv2DTranspose(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(conv)
    conv = Activation(act)(conv)

  return conv
  
'''
  Attention block/mechanism
'''
def attention_block(x, gating, inter_shape, drop_rate=0.25):
   
    # Find shape of inputs
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)

    ## Process x vector and gating signal
    # x vector input and processing
    theta_x = Conv2D(inter_shape, kernel_size = 1, strides = 1, padding='same', kernel_initializer='he_normal', activation=None)(x)
    theta_x = MaxPooling2D((2,2))(theta_x)
    shape_theta_x = K.int_shape(theta_x)

    # gating signal ""
    phi_g = Conv2D(inter_shape, kernel_size = 1, strides = 1, padding='same', kernel_initializer='he_normal', activation=None)(gating)
    shape_phi_g = K.int_shape(phi_g)

    # Add components
    concat_xg = add([phi_g, theta_x])
    act_xg = Activation('relu')(concat_xg)

    # Apply convolution
    psi = Conv2D(1, kernel_size = 1, strides = 1, padding='same', kernel_initializer='he_normal', activation=None)(act_xg)

    # Apply sigmoid activation
    sigmoid_xg = Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)

    # UpSample and resample to correct size
    upsample_psi = UpSampling2D(interpolation='bilinear', size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg)
    upsample_psi = tf.broadcast_to(upsample_psi, shape=shape_x)
    y = multiply([upsample_psi, x])

    return y


'''
  Attention U-Net model
'''

def UNetAM(trained_weights = None, input_size = (512,512,3), drop_rate = 0.25, lr=0.0001, filter_base=16):

    ## Can add pretrained weights by specifying 'trained_weights'

    # Input layer
    inputs = Input(input_size, batch_size=1)

    ## Contraction phase
    conv = convBlock2(inputs, filter_base, 3)
    #conv0 = Dropout(drop_rate)(conv0)

    conv0 = MaxPooling2D(pool_size=(2, 2))(conv)
    conv0 = convBlock2(conv0, 2 * filter_base, 3)

    pool0 = MaxPooling2D(pool_size=(2, 2))(conv0)
    conv1 = convBlock2(pool0, 4 * filter_base, 3)
    #conv1 = Dropout(drop_rate)(conv1)

    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = convBlock2(pool1, 8 * filter_base, 3)
    #conv2 = Dropout(drop_rate)(conv2)

    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = convBlock2(pool2, 16 * filter_base, 3)
    #conv3 = Dropout(drop_rate)(conv3)

    ## Expansion phase
    up4 = (Conv2DTranspose(8 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv3))
    merge4 = attention_block(conv2, conv3, 8 * filter_base, drop_rate) # Attention gate
    conv4 = concatenate([up4, merge4])
    conv4 = convBlock2(conv4, 8 * filter_base, 3)

    up5 = (Conv2DTranspose(4 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv4))
    merge5 = attention_block(conv1, conv4, 4 * filter_base, drop_rate) # Attention gate
    conv5 = concatenate([up5, merge5])
    conv5 = convBlock2(conv5, 4 * filter_base, 3)

    up6 = (Conv2DTranspose(2 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv5))
    merge6 = attention_block(conv0, conv5, 2 * filter_base, drop_rate) # Attention gate
    conv6 = concatenate([up6, merge6])
    conv6 = convBlock2(conv6, 2 * filter_base, 3)

    up7 = (Conv2DTranspose(1 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv6))
    merge7 = attention_block(conv, conv6, 1 * filter_base, drop_rate)
# 应该合并上采样输出和注意力加权后的跳跃连接
    conv7 = concatenate([up7, merge7]) 
    conv7 = convBlock2(conv7, 1 * filter_base, 3)

    ## Output layer
    out = convBlock(conv7, 1, 1, act='sigmoid')

    model = Model(inputs, out)

    # model.compile(optimizer = Adam(learning_rate = lr), loss = 'binary_crossentropy', metrics = ['accuracy', 'mse'])
    model.compile(optimizer = Adam(learning_rate = lr), loss = bce_dice_loss_weighted, metrics = ['accuracy', iou_metric])
    if trained_weights != None:
    	model.load_weights(trained_weights)

    return model

# %%
# Print model layers and number of parameters
UNetAM().summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(1, 512, 512, 3)]   0           []
#
#  conv2d_19 (Conv2D)             (1, 512, 512, 16)    448         ['input_2[0][0]']
#
#  activation_19 (Activation)     (1, 512, 512, 16)    0           ['conv2d_19[0][0]']
#
#  conv2d_20 (Conv2D)             (1, 512, 512, 16)    2320        ['activation_19[0][0]']
#
#  activation_20 (Activation)     (1, 512, 512, 16)    0           ['conv2d_20[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (1, 256, 256, 16)   0           ['activation_20[0][0]']
#
#  conv2d_21 (Conv2D)             (1, 256, 256, 32)    4640        ['max_pooling2d_4[0][0]']
#
#  activation_21 (Activation)     (1, 256, 256, 32)    0           ['conv2d_21[0][0]']
#
#  conv2d_22 (Conv2D)             (1, 256, 256, 32)    9248        ['activation_21[0][0]']
#
#  activation_22 (Activation)     (1, 256, 256, 32)    0           ['conv2d_22[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (1, 128, 128, 32)   0           ['activation_22[0][0]']
#
#  conv2d_23 (Conv2D)             (1, 128, 128, 64)    18496       ['max_pooling2d_5[0][0]']
#
#  activation_23 (Activation)     (1, 128, 128, 64)    0           ['conv2d_23[0][0]']
#
#  conv2d_24 (Conv2D)             (1, 128, 128, 64)    36928       ['activation_23[0][0]']
#
#  activation_24 (Activation)     (1, 128, 128, 64)    0           ['conv2d_24[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (1, 64, 64, 64)     0           ['activation_24[0][0]']
#
#  conv2d_25 (Conv2D)             (1, 64, 64, 128)     73856       ['max_pooling2d_6[0][0]']
#
#  activation_25 (Activation)     (1, 64, 64, 128)     0           ['conv2d_25[0][0]']
#
#  conv2d_26 (Conv2D)             (1, 64, 64, 128)     147584      ['activation_25[0][0]']
#
#  activation_26 (Activation)     (1, 64, 64, 128)     0           ['conv2d_26[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (1, 32, 32, 128)    0           ['activation_26[0][0]']
#
#  conv2d_27 (Conv2D)             (1, 32, 32, 256)     295168      ['max_pooling2d_7[0][0]']
#
#  activation_27 (Activation)     (1, 32, 32, 256)     0           ['conv2d_27[0][0]']
#
#  conv2d_28 (Conv2D)             (1, 32, 32, 256)     590080      ['activation_27[0][0]']
#
#  activation_28 (Activation)     (1, 32, 32, 256)     0           ['conv2d_28[0][0]']
#
#  conv2d_29 (Conv2D)             (1, 64, 64, 128)     16512       ['activation_26[0][0]']
#
#  conv2d_30 (Conv2D)             (1, 32, 32, 128)     32896       ['activation_28[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (1, 32, 32, 128)    0           ['conv2d_29[0][0]']
#
#  add (Add)                      (1, 32, 32, 128)     0           ['conv2d_30[0][0]',
#                                                                   'max_pooling2d_8[0][0]']
#
#  activation_29 (Activation)     (1, 32, 32, 128)     0           ['add[0][0]']
#
#  conv2d_31 (Conv2D)             (1, 32, 32, 1)       129         ['activation_29[0][0]']
#
#  activation_30 (Activation)     (1, 32, 32, 1)       0           ['conv2d_31[0][0]']
#
#  up_sampling2d (UpSampling2D)   (1, 64, 64, 1)       0           ['activation_30[0][0]']
#
#  tf.broadcast_to (TFOpLambda)   (1, 64, 64, 128)     0           ['up_sampling2d[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (1, 64, 64, 128)    131200      ['activation_28[0][0]']
#  spose)
#
#  multiply (Multiply)            (1, 64, 64, 128)     0           ['tf.broadcast_to[0][0]',
#                                                                   'activation_26[0][0]']
#
#  concatenate_4 (Concatenate)    (1, 64, 64, 256)     0           ['conv2d_transpose_4[0][0]',
#                                                                   'multiply[0][0]']
#
#  conv2d_32 (Conv2D)             (1, 64, 64, 128)     295040      ['concatenate_4[0][0]']
#
#  activation_31 (Activation)     (1, 64, 64, 128)     0           ['conv2d_32[0][0]']
#
#  conv2d_33 (Conv2D)             (1, 64, 64, 128)     147584      ['activation_31[0][0]']
#
#  activation_32 (Activation)     (1, 64, 64, 128)     0           ['conv2d_33[0][0]']
#
#  conv2d_34 (Conv2D)             (1, 128, 128, 64)    4160        ['activation_24[0][0]']
#
#  conv2d_35 (Conv2D)             (1, 64, 64, 64)      8256        ['activation_32[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (1, 64, 64, 64)     0           ['conv2d_34[0][0]']
#
#  add_1 (Add)                    (1, 64, 64, 64)      0           ['conv2d_35[0][0]',
#                                                                   'max_pooling2d_9[0][0]']
#
#  activation_33 (Activation)     (1, 64, 64, 64)      0           ['add_1[0][0]']
#
#  conv2d_36 (Conv2D)             (1, 64, 64, 1)       65          ['activation_33[0][0]']
#
#  activation_34 (Activation)     (1, 64, 64, 1)       0           ['conv2d_36[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (1, 128, 128, 1)    0           ['activation_34[0][0]']
#
#  tf.broadcast_to_1 (TFOpLambda)  (1, 128, 128, 64)   0           ['up_sampling2d_1[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (1, 128, 128, 64)   32832       ['activation_32[0][0]']
#  spose)
#
#  multiply_1 (Multiply)          (1, 128, 128, 64)    0           ['tf.broadcast_to_1[0][0]',
#                                                                   'activation_24[0][0]']
#
#  concatenate_5 (Concatenate)    (1, 128, 128, 128)   0           ['conv2d_transpose_5[0][0]',
#                                                                   'multiply_1[0][0]']
#
#  conv2d_37 (Conv2D)             (1, 128, 128, 64)    73792       ['concatenate_5[0][0]']
#
#  activation_35 (Activation)     (1, 128, 128, 64)    0           ['conv2d_37[0][0]']
#
#  conv2d_38 (Conv2D)             (1, 128, 128, 64)    36928       ['activation_35[0][0]']
#
#  activation_36 (Activation)     (1, 128, 128, 64)    0           ['conv2d_38[0][0]']
#
#  conv2d_39 (Conv2D)             (1, 256, 256, 32)    1056        ['activation_22[0][0]']
#
#  conv2d_40 (Conv2D)             (1, 128, 128, 32)    2080        ['activation_36[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (1, 128, 128, 32)   0           ['conv2d_39[0][0]']
#  )
#
#  add_2 (Add)                    (1, 128, 128, 32)    0           ['conv2d_40[0][0]',
#                                                                   'max_pooling2d_10[0][0]']
#
#  activation_37 (Activation)     (1, 128, 128, 32)    0           ['add_2[0][0]']
#
#  conv2d_41 (Conv2D)             (1, 128, 128, 1)     33          ['activation_37[0][0]']
#
#  activation_38 (Activation)     (1, 128, 128, 1)     0           ['conv2d_41[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (1, 256, 256, 1)    0           ['activation_38[0][0]']
#
#  tf.broadcast_to_2 (TFOpLambda)  (1, 256, 256, 32)   0           ['up_sampling2d_2[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (1, 256, 256, 32)   8224        ['activation_36[0][0]']
#  spose)
#
#  multiply_2 (Multiply)          (1, 256, 256, 32)    0           ['tf.broadcast_to_2[0][0]',
#                                                                   'activation_22[0][0]']
#
#  concatenate_6 (Concatenate)    (1, 256, 256, 64)    0           ['conv2d_transpose_6[0][0]',
#                                                                   'multiply_2[0][0]']
#
#  conv2d_42 (Conv2D)             (1, 256, 256, 32)    18464       ['concatenate_6[0][0]']
#
#  activation_39 (Activation)     (1, 256, 256, 32)    0           ['conv2d_42[0][0]']
#
#  conv2d_43 (Conv2D)             (1, 256, 256, 32)    9248        ['activation_39[0][0]']
#
#  activation_40 (Activation)     (1, 256, 256, 32)    0           ['conv2d_43[0][0]']
#
#  conv2d_44 (Conv2D)             (1, 512, 512, 16)    272         ['activation_20[0][0]']
#
#  conv2d_45 (Conv2D)             (1, 256, 256, 16)    528         ['activation_40[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (1, 256, 256, 16)   0           ['conv2d_44[0][0]']
#  )
#
#  add_3 (Add)                    (1, 256, 256, 16)    0           ['conv2d_45[0][0]',
#                                                                   'max_pooling2d_11[0][0]']
#
#  activation_41 (Activation)     (1, 256, 256, 16)    0           ['add_3[0][0]']
#
#  conv2d_46 (Conv2D)             (1, 256, 256, 1)     17          ['activation_41[0][0]']
#
#  activation_42 (Activation)     (1, 256, 256, 1)     0           ['conv2d_46[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (1, 512, 512, 1)    0           ['activation_42[0][0]']
#
#  tf.broadcast_to_3 (TFOpLambda)  (1, 512, 512, 16)   0           ['up_sampling2d_3[0][0]']
#
#  conv2d_transpose_7 (Conv2DTran  (1, 512, 512, 16)   2064        ['activation_40[0][0]']
#  spose)
#
#  multiply_3 (Multiply)          (1, 512, 512, 16)    0           ['tf.broadcast_to_3[0][0]',
#                                                                   'activation_20[0][0]']
#
#  concatenate_7 (Concatenate)    (1, 512, 512, 32)    0           ['conv2d_transpose_7[0][0]',
#                                                                   'multiply_3[0][0]']
#
#  conv2d_47 (Conv2D)             (1, 512, 512, 16)    4624        ['concatenate_7[0][0]']
#
#  activation_43 (Activation)     (1, 512, 512, 16)    0           ['conv2d_47[0][0]']
#
#  conv2d_48 (Conv2D)             (1, 512, 512, 16)    2320        ['activation_43[0][0]']
#
#  activation_44 (Activation)     (1, 512, 512, 16)    0           ['conv2d_48[0][0]']
#
#  conv2d_49 (Conv2D)             (1, 512, 512, 1)     17          ['activation_44[0][0]']
#
#  activation_45 (Activation)     (1, 512, 512, 1)     0           ['conv2d_49[0][0]']
#
# ==================================================================================================
# Total params: 2,007,109
# Trainable params: 2,007,109
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## ResNet50-SegNet

# %%
# Forked code from: https://github.com/ykamikawa/tf-keras-SegNet

from keras.layers import Layer

'''
  Unpooling using max pooling indices
'''

class MaxPoolingWithArgmax2D(Layer):
    def __init__(self, pool_size=(2, 2), strides=(2, 2), padding="same", **kwargs):
        super(MaxPoolingWithArgmax2D, self).__init__(**kwargs)

    def call(self, inputs, **kwargs):
        padding = 'same'
        pool_size = (2,2)
        strides = (2,2)
        if K.backend() == "tensorflow":
            ksize = [1, pool_size[0], pool_size[1], 1]
            padding = padding.upper()
            strides = [1, strides[0], strides[1], 1]
            output, argmax = tf.nn.max_pool_with_argmax(
                inputs, ksize=ksize, strides=strides, padding=padding
            )
        else:
            errmsg = "{} backend is not supported for layer {}".format(
                K.backend(), type(self).__name__
            )
            raise NotImplementedError(errmsg)
        argmax = K.cast(argmax, K.floatx())
        return [output, argmax]

class MaxUnpooling2D(Layer):
    def __init__(self, size=(2, 2), **kwargs):
        super(MaxUnpooling2D, self).__init__(**kwargs)
        self.size = size

    def call(self, inputs, output_shape=None):
        updates, mask = inputs[0], inputs[1]
        with tf.compat.v1.variable_scope(self.name):
            mask = K.cast(mask, "int32")
            input_shape = tf.shape(updates, out_type="int32")
            #  calculation new shape
            if output_shape is None:
                output_shape = (
                    input_shape[0],
                    input_shape[1] * self.size[0],
                    input_shape[2] * self.size[1],
                    input_shape[3],
                )
            self.output_shape1 = output_shape

            # calculation indices for batch, height, width and feature maps
            one_like_mask = K.ones_like(mask, dtype="int32")
            batch_shape = K.concatenate([[input_shape[0]], [1], [1], [1]], axis=0)
            batch_range = K.reshape(
                tf.range(output_shape[0], dtype="int32"), shape=batch_shape
            )
            b = one_like_mask * batch_range
            y = mask // (output_shape[2] * output_shape[3])
            x = (mask // output_shape[3]) % output_shape[2]
            feature_range = tf.range(output_shape[3], dtype="int32")
            f = one_like_mask * feature_range

            # transpose indices & reshape update values to one dimension
            updates_size = tf.size(updates)
            indices = K.transpose(K.reshape(K.stack([b, y, x, f]), [4, updates_size]))
            values = K.reshape(updates, [updates_size])
            ret = tf.scatter_nd(indices, values, output_shape)
            return ret

    def compute_output_shape(self, input_shape):
        mask_shape = input_shape[1]
        return (
            mask_shape[0],
            mask_shape[1] * self.size[0],
            mask_shape[2] * self.size[1],
            mask_shape[3],
        )

# Custom version of MaxUnpooling2D
# Takes raw layer values and outputs values
# Takes tf.nn.max_pool_with_argmax output as input
def unpool_with_indices(pool, indices, out_size=2):
  print(pool)
  print(indices)
  # Create empty array of appropriate size
  shape = np.array(np.shape(pool))
  shape = np.array((shape[0], out_size * shape[1], out_size * shape[2], shape[3]))
  out = np.zeros(shape)

  # Make upsample
  inds = np.array(indices).flatten()
  outs = np.array(pool).flatten()
  for i in range(len(inds)):
    blk = inds[i] // (shape[2] * shape[3]) # Find which block to place numbers in
    ln  = inds[i] - (blk * shape[3] * shape[2]) # Find which line
    ln2 = ln // (shape[3]) # Find line
    pos = ln % (shape[3]) # Find position
    #print(blk, ln2, pos)
    out[0][blk][ln2][pos] = outs[i]


  #print(out.shape)
  return (out)

# Own custom code
'''
  ResNet Contraction Phase Block
'''

def resnetConvDownBlock(x, filter, kernel, act='relu'):
  # Convolutional Block for encoding phase
  for i in range(3):
    x = ZeroPadding2D((1,1))(x)
    x = Conv2D(filters = filter, kernel_size = kernel, kernel_initializer = 'he_normal')(x)
    x = Activation('relu')(x)
    
  return x

'''
  SegNet Expansion Phase Block
'''
def resnetConvUpBlock(x, skip_connection = None, filter = None, kernel = None, act='relu'):
  # Convolutional block for decoding phase
  
  out = x

  # Unpooling
  out = UpSampling2D((2,2))(out)

  # Conv Block
  for i in range(3):
    out = ZeroPadding2D((1,1))(out)
    out = Conv2D(filters = filter, kernel_size = kernel, kernel_initializer = 'he_normal')(out)
    out = Activation('relu')(out)

  # Implement skip connection
  if skip_connection != None:
    out = Add()([out, skip_connection])

  return out

def ResNet50SegNet(input_size=(512,512,3), lr = 0.0001, filters = 64, kernel_sz = 3):

  inputs = Input(input_size)

  # Encoder
  # Conv, Conv, Conv, MaxPool #1
  block1 = resnetConvDownBlock(inputs, filter = filters, kernel = kernel_sz)
  pool1, mask1 = MaxPoolingWithArgmax2D((2,2))(block1)
  # Conv, Conv, Conv, MaxPool #2
  block2 = resnetConvDownBlock(pool1, filter = 2 * filters, kernel = kernel_sz)
  pool2, mask2 = MaxPoolingWithArgmax2D((2,2))(block2)
  # Conv, Conv, Conv, MaxPool #3
  block3 = resnetConvDownBlock(pool2, filter = 4 * filters, kernel = kernel_sz)
  pool3, mask3 = MaxPoolingWithArgmax2D((2,2))(block3)
  # Conv, Conv, Conv, MaxPool #4
  block4 = resnetConvDownBlock(pool3, filter = 8 * filters, kernel = kernel_sz)
  pool4, mask4 = MaxPoolingWithArgmax2D((2,2))(block4)
  # Conv, Conv, Conv, MaxPool #5
  block5 = resnetConvDownBlock(pool4, filter = 16 * filters, kernel = kernel_sz)
  pool5, mask5 = MaxPoolingWithArgmax2D((2,2))(block5)

  # Decoder
  # ConvTranspose + Concat, Conv, Conv, Conv #1
  block5_ = resnetConvUpBlock(pool5, filter = 16 * filters, kernel = kernel_sz)
  # ConvTranspose + Concat, Conv, Conv, Conv #2
  block4_ = resnetConvUpBlock(block5_, skip_connection = MaxUnpooling2D((2,2))([pool4, mask4]), filter = 8 * filters, kernel = kernel_sz)
  # ConvTranspose + Concat, Conv, Conv, Conv #3
  block3_ = resnetConvUpBlock(block4_, skip_connection = MaxUnpooling2D((2,2))([pool3, mask3]), filter = 4 * filters, kernel = kernel_sz)
  # ConvTranspose + Concat, Conv, Conv, Conv #4
  block2_ = resnetConvUpBlock(block3_, skip_connection = MaxUnpooling2D((2,2))([pool2, mask2]), filter = 2 * filters, kernel = kernel_sz)
  # ConvTranspose + Concat, Conv, Conv, Conv #5
  block1_ = resnetConvUpBlock(block2_, skip_connection = MaxUnpooling2D((2,2))([pool1, mask1]), filter = filters, kernel = kernel_sz)
  
  # Output
  outputs = Conv2D(1, kernel_size = 1, strides = 1, kernel_initializer = 'he_normal')(block1_)
  outputs = Activation('sigmoid')(outputs)

  model = Model(inputs, outputs)
  # model.compile(optimizer = Adam(learning_rate = lr), loss = 'binary_crossentropy', metrics = ['accuracy', 'mse'])
  model.compile(optimizer = Adam(learning_rate = lr), loss = bce_dice_loss_weighted, metrics = ['accuracy', iou_metric])

  return model

# %%
# Print model layers and number of parameters
ResNet50SegNet().summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 514, 514, 3)  0          ['input_3[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 512, 512, 64  1792        ['zero_padding2d[0][0]']
#                                 )
#
#  activation_46 (Activation)     (None, 512, 512, 64  0           ['conv2d_50[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 514, 514, 64  0          ['activation_46[0][0]']
#  D)                             )
#
#  conv2d_51 (Conv2D)             (None, 512, 512, 64  36928       ['zero_padding2d_1[0][0]']
#                                 )
#
#  activation_47 (Activation)     (None, 512, 512, 64  0           ['conv2d_51[0][0]']
#                                 )
#
#  zero_padding2d_2 (ZeroPadding2  (None, 514, 514, 64  0          ['activation_47[0][0]']
#  D)                             )
#
#  conv2d_52 (Conv2D)             (None, 512, 512, 64  36928       ['zero_padding2d_2[0][0]']
#                                 )
#
#  activation_48 (Activation)     (None, 512, 512, 64  0           ['conv2d_52[0][0]']
#                                 )
#
#  max_pooling_with_argmax2d (Max  [(None, 256, 256, 6  0          ['activation_48[0][0]']
#  PoolingWithArgmax2D)           4),
#                                  (None, 256, 256, 6
#                                 4)]
#
#  zero_padding2d_3 (ZeroPadding2  (None, 258, 258, 64  0          ['max_pooling_with_argmax2d[0][0]
#  D)                             )                                ']
#
#  conv2d_53 (Conv2D)             (None, 256, 256, 12  73856       ['zero_padding2d_3[0][0]']
#                                 8)
#
#  activation_49 (Activation)     (None, 256, 256, 12  0           ['conv2d_53[0][0]']
#                                 8)
#
#  zero_padding2d_4 (ZeroPadding2  (None, 258, 258, 12  0          ['activation_49[0][0]']
#  D)                             8)
#
#  conv2d_54 (Conv2D)             (None, 256, 256, 12  147584      ['zero_padding2d_4[0][0]']
#                                 8)
#
#  activation_50 (Activation)     (None, 256, 256, 12  0           ['conv2d_54[0][0]']
#                                 8)
#
#  zero_padding2d_5 (ZeroPadding2  (None, 258, 258, 12  0          ['activation_50[0][0]']
#  D)                             8)
#
#  conv2d_55 (Conv2D)             (None, 256, 256, 12  147584      ['zero_padding2d_5[0][0]']
#                                 8)
#
#  activation_51 (Activation)     (None, 256, 256, 12  0           ['conv2d_55[0][0]']
#                                 8)
#
#  max_pooling_with_argmax2d_1 (M  [(None, 128, 128, 1  0          ['activation_51[0][0]']
#  axPoolingWithArgmax2D)         28),
#                                  (None, 128, 128, 1
#                                 28)]
#
#  zero_padding2d_6 (ZeroPadding2  (None, 130, 130, 12  0          ['max_pooling_with_argmax2d_1[0][
#  D)                             8)                               0]']
#
#  conv2d_56 (Conv2D)             (None, 128, 128, 25  295168      ['zero_padding2d_6[0][0]']
#                                 6)
#
#  activation_52 (Activation)     (None, 128, 128, 25  0           ['conv2d_56[0][0]']
#                                 6)
#
#  zero_padding2d_7 (ZeroPadding2  (None, 130, 130, 25  0          ['activation_52[0][0]']
#  D)                             6)
#
#  conv2d_57 (Conv2D)             (None, 128, 128, 25  590080      ['zero_padding2d_7[0][0]']
#                                 6)
#
#  activation_53 (Activation)     (None, 128, 128, 25  0           ['conv2d_57[0][0]']
#                                 6)
#
#  zero_padding2d_8 (ZeroPadding2  (None, 130, 130, 25  0          ['activation_53[0][0]']
#  D)                             6)
#
#  conv2d_58 (Conv2D)             (None, 128, 128, 25  590080      ['zero_padding2d_8[0][0]']
#                                 6)
#
#  activation_54 (Activation)     (None, 128, 128, 25  0           ['conv2d_58[0][0]']
#                                 6)
#
#  max_pooling_with_argmax2d_2 (M  [(None, 64, 64, 256  0          ['activation_54[0][0]']
#  axPoolingWithArgmax2D)         ),
#                                  (None, 64, 64, 256
#                                 )]
#
#  zero_padding2d_9 (ZeroPadding2  (None, 66, 66, 256)  0          ['max_pooling_with_argmax2d_2[0][
#  D)                                                              0]']
#
#  conv2d_59 (Conv2D)             (None, 64, 64, 512)  1180160     ['zero_padding2d_9[0][0]']
#
#  activation_55 (Activation)     (None, 64, 64, 512)  0           ['conv2d_59[0][0]']
#
#  zero_padding2d_10 (ZeroPadding  (None, 66, 66, 512)  0          ['activation_55[0][0]']
#  2D)
#
#  conv2d_60 (Conv2D)             (None, 64, 64, 512)  2359808     ['zero_padding2d_10[0][0]']
#
#  activation_56 (Activation)     (None, 64, 64, 512)  0           ['conv2d_60[0][0]']
#
#  zero_padding2d_11 (ZeroPadding  (None, 66, 66, 512)  0          ['activation_56[0][0]']
#  2D)
#
#  conv2d_61 (Conv2D)             (None, 64, 64, 512)  2359808     ['zero_padding2d_11[0][0]']
#
#  activation_57 (Activation)     (None, 64, 64, 512)  0           ['conv2d_61[0][0]']
#
#  max_pooling_with_argmax2d_3 (M  [(None, 32, 32, 512  0          ['activation_57[0][0]']
#  axPoolingWithArgmax2D)         ),
#                                  (None, 32, 32, 512
#                                 )]
#
#  zero_padding2d_12 (ZeroPadding  (None, 34, 34, 512)  0          ['max_pooling_with_argmax2d_3[0][
#  2D)                                                             0]']
#
#  conv2d_62 (Conv2D)             (None, 32, 32, 1024  4719616     ['zero_padding2d_12[0][0]']
#                                 )
#
#  activation_58 (Activation)     (None, 32, 32, 1024  0           ['conv2d_62[0][0]']
#                                 )
#
#  zero_padding2d_13 (ZeroPadding  (None, 34, 34, 1024  0          ['activation_58[0][0]']
#  2D)                            )
#
#  conv2d_63 (Conv2D)             (None, 32, 32, 1024  9438208     ['zero_padding2d_13[0][0]']
#                                 )
#
#  activation_59 (Activation)     (None, 32, 32, 1024  0           ['conv2d_63[0][0]']
#                                 )
#
#  zero_padding2d_14 (ZeroPadding  (None, 34, 34, 1024  0          ['activation_59[0][0]']
#  2D)                            )
#
#  conv2d_64 (Conv2D)             (None, 32, 32, 1024  9438208     ['zero_padding2d_14[0][0]']
#                                 )
#
#  activation_60 (Activation)     (None, 32, 32, 1024  0           ['conv2d_64[0][0]']
#                                 )
#
#  max_pooling_with_argmax2d_4 (M  [(None, 16, 16, 102  0          ['activation_60[0][0]']
#  axPoolingWithArgmax2D)         4),
#                                  (None, 16, 16, 102
#                                 4)]
#
#  up_sampling2d_4 (UpSampling2D)  (None, 32, 32, 1024  0          ['max_pooling_with_argmax2d_4[0][
#                                 )                                0]']
#
#  zero_padding2d_15 (ZeroPadding  (None, 34, 34, 1024  0          ['up_sampling2d_4[0][0]']
#  2D)                            )
#
#  conv2d_65 (Conv2D)             (None, 32, 32, 1024  9438208     ['zero_padding2d_15[0][0]']
#                                 )
#
#  activation_61 (Activation)     (None, 32, 32, 1024  0           ['conv2d_65[0][0]']
#                                 )
#
#  zero_padding2d_16 (ZeroPadding  (None, 34, 34, 1024  0          ['activation_61[0][0]']
#  2D)                            )
#
#  conv2d_66 (Conv2D)             (None, 32, 32, 1024  9438208     ['zero_padding2d_16[0][0]']
#                                 )
#
#  activation_62 (Activation)     (None, 32, 32, 1024  0           ['conv2d_66[0][0]']
#                                 )
#
#  zero_padding2d_17 (ZeroPadding  (None, 34, 34, 1024  0          ['activation_62[0][0]']
#  2D)                            )
#
#  conv2d_67 (Conv2D)             (None, 32, 32, 1024  9438208     ['zero_padding2d_17[0][0]']
#                                 )
#
#  activation_63 (Activation)     (None, 32, 32, 1024  0           ['conv2d_67[0][0]']
#                                 )
#
#  up_sampling2d_5 (UpSampling2D)  (None, 64, 64, 1024  0          ['activation_63[0][0]']
#                                 )
#
#  zero_padding2d_18 (ZeroPadding  (None, 66, 66, 1024  0          ['up_sampling2d_5[0][0]']
#  2D)                            )
#
#  conv2d_68 (Conv2D)             (None, 64, 64, 512)  4719104     ['zero_padding2d_18[0][0]']
#
#  activation_64 (Activation)     (None, 64, 64, 512)  0           ['conv2d_68[0][0]']
#
#  zero_padding2d_19 (ZeroPadding  (None, 66, 66, 512)  0          ['activation_64[0][0]']
#  2D)
#
#  conv2d_69 (Conv2D)             (None, 64, 64, 512)  2359808     ['zero_padding2d_19[0][0]']
#
#  activation_65 (Activation)     (None, 64, 64, 512)  0           ['conv2d_69[0][0]']
#
#  zero_padding2d_20 (ZeroPadding  (None, 66, 66, 512)  0          ['activation_65[0][0]']
#  2D)
#
#  conv2d_70 (Conv2D)             (None, 64, 64, 512)  2359808     ['zero_padding2d_20[0][0]']
#
#  activation_66 (Activation)     (None, 64, 64, 512)  0           ['conv2d_70[0][0]']
#
#  max_unpooling2d (MaxUnpooling2  (None, 64, 64, 512)  0          ['max_pooling_with_argmax2d_3[0][
#  D)                                                              0]',
#                                                                   'max_pooling_with_argmax2d_3[0][
#                                                                  1]']
#
#  add_4 (Add)                    (None, 64, 64, 512)  0           ['activation_66[0][0]',
#                                                                   'max_unpooling2d[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 128, 128, 51  0          ['add_4[0][0]']
#                                 2)
#
#  zero_padding2d_21 (ZeroPadding  (None, 130, 130, 51  0          ['up_sampling2d_6[0][0]']
#  2D)                            2)
#
#  conv2d_71 (Conv2D)             (None, 128, 128, 25  1179904     ['zero_padding2d_21[0][0]']
#                                 6)
#
#  activation_67 (Activation)     (None, 128, 128, 25  0           ['conv2d_71[0][0]']
#                                 6)
#
#  zero_padding2d_22 (ZeroPadding  (None, 130, 130, 25  0          ['activation_67[0][0]']
#  2D)                            6)
#
#  conv2d_72 (Conv2D)             (None, 128, 128, 25  590080      ['zero_padding2d_22[0][0]']
#                                 6)
#
#  activation_68 (Activation)     (None, 128, 128, 25  0           ['conv2d_72[0][0]']
#                                 6)
#
#  zero_padding2d_23 (ZeroPadding  (None, 130, 130, 25  0          ['activation_68[0][0]']
#  2D)                            6)
#
#  conv2d_73 (Conv2D)             (None, 128, 128, 25  590080      ['zero_padding2d_23[0][0]']
#                                 6)
#
#  activation_69 (Activation)     (None, 128, 128, 25  0           ['conv2d_73[0][0]']
#                                 6)
#
#  max_unpooling2d_1 (MaxUnpoolin  (None, 128, 128, 25  0          ['max_pooling_with_argmax2d_2[0][
#  g2D)                           6)                               0]',
#                                                                   'max_pooling_with_argmax2d_2[0][
#                                                                  1]']
#
#  add_5 (Add)                    (None, 128, 128, 25  0           ['activation_69[0][0]',
#                                 6)                                'max_unpooling2d_1[0][0]']
#
#  up_sampling2d_7 (UpSampling2D)  (None, 256, 256, 25  0          ['add_5[0][0]']
#                                 6)
#
#  zero_padding2d_24 (ZeroPadding  (None, 258, 258, 25  0          ['up_sampling2d_7[0][0]']
#  2D)                            6)
#
#  conv2d_74 (Conv2D)             (None, 256, 256, 12  295040      ['zero_padding2d_24[0][0]']
#                                 8)
#
#  activation_70 (Activation)     (None, 256, 256, 12  0           ['conv2d_74[0][0]']
#                                 8)
#
#  zero_padding2d_25 (ZeroPadding  (None, 258, 258, 12  0          ['activation_70[0][0]']
#  2D)                            8)
#
#  conv2d_75 (Conv2D)             (None, 256, 256, 12  147584      ['zero_padding2d_25[0][0]']
#                                 8)
#
#  activation_71 (Activation)     (None, 256, 256, 12  0           ['conv2d_75[0][0]']
#                                 8)
#
#  zero_padding2d_26 (ZeroPadding  (None, 258, 258, 12  0          ['activation_71[0][0]']
#  2D)                            8)
#
#  conv2d_76 (Conv2D)             (None, 256, 256, 12  147584      ['zero_padding2d_26[0][0]']
#                                 8)
#
#  activation_72 (Activation)     (None, 256, 256, 12  0           ['conv2d_76[0][0]']
#                                 8)
#
#  max_unpooling2d_2 (MaxUnpoolin  (None, 256, 256, 12  0          ['max_pooling_with_argmax2d_1[0][
#  g2D)                           8)                               0]',
#                                                                   'max_pooling_with_argmax2d_1[0][
#                                                                  1]']
#
#  add_6 (Add)                    (None, 256, 256, 12  0           ['activation_72[0][0]',
#                                 8)                                'max_unpooling2d_2[0][0]']
#
#  up_sampling2d_8 (UpSampling2D)  (None, 512, 512, 12  0          ['add_6[0][0]']
#                                 8)
#
#  zero_padding2d_27 (ZeroPadding  (None, 514, 514, 12  0          ['up_sampling2d_8[0][0]']
#  2D)                            8)
#
#  conv2d_77 (Conv2D)             (None, 512, 512, 64  73792       ['zero_padding2d_27[0][0]']
#                                 )
#
#  activation_73 (Activation)     (None, 512, 512, 64  0           ['conv2d_77[0][0]']
#                                 )
#
#  zero_padding2d_28 (ZeroPadding  (None, 514, 514, 64  0          ['activation_73[0][0]']
#  2D)                            )
#
#  conv2d_78 (Conv2D)             (None, 512, 512, 64  36928       ['zero_padding2d_28[0][0]']
#                                 )
#
#  activation_74 (Activation)     (None, 512, 512, 64  0           ['conv2d_78[0][0]']
#                                 )
#
#  zero_padding2d_29 (ZeroPadding  (None, 514, 514, 64  0          ['activation_74[0][0]']
#  2D)                            )
#
#  conv2d_79 (Conv2D)             (None, 512, 512, 64  36928       ['zero_padding2d_29[0][0]']
#                                 )
#
#  activation_75 (Activation)     (None, 512, 512, 64  0           ['conv2d_79[0][0]']
#                                 )
#
#  max_unpooling2d_3 (MaxUnpoolin  (None, 512, 512, 64  0          ['max_pooling_with_argmax2d[0][0]
#  g2D)                           )                                ',
#                                                                   'max_pooling_with_argmax2d[0][1]
#                                                                  ']
#
#  add_7 (Add)                    (None, 512, 512, 64  0           ['activation_75[0][0]',
#                                 )                                 'max_unpooling2d_3[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 512, 512, 1)  65          ['add_7[0][0]']
#
#  activation_76 (Activation)     (None, 512, 512, 1)  0           ['conv2d_80[0][0]']
#
# ==================================================================================================
# Total params: 72,267,137
# Trainable params: 72,267,137
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## FCN32-VGG16

# %%
# Code forked and modified from: https://github.com/divamgupta/image-segmentation-keras

'''
  FCN32-VGG16 model
'''

def fcn_32(input_size = (512,512,3), lr = 0.0001, drop_rate = 0):
  
    kernel = 3
    filter_size = 64
    pad = 1
    pool_size = 2

    IMAGE_ORDERING = 'channels_last'
    # Input
    inputs = Input(shape=input_size)

    x = inputs
    levels = []

    ## Encoder
    # Block 1
    x = Conv2D(64, (3, 3), padding='same',
               name='block1_conv1', data_format=IMAGE_ORDERING)(inputs)
    x = Activation('relu')(x)
    x = Conv2D(64, (3, 3), padding='same',
               name='block1_conv2', data_format=IMAGE_ORDERING)(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool',
                     data_format=IMAGE_ORDERING)(x)
    levels.append(x)

    # Block 2
    x = Conv2D(128, (3, 3), padding='same',
               name='block2_conv1', data_format=IMAGE_ORDERING)(x)
    x = Activation('relu')(x)
    x = Conv2D(128, (3, 3), padding='same',
               name='block2_conv2', data_format=IMAGE_ORDERING)(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool',
                     data_format=IMAGE_ORDERING)(x)
    levels.append(x)

    # Block 3
    x = Conv2D(256, (3, 3), padding='same',
               name='block3_conv1', data_format=IMAGE_ORDERING)(x)
    x = Activation('relu')(x)
    x = Conv2D(256, (3, 3), padding='same',
               name='block3_conv2', data_format=IMAGE_ORDERING)(x)
    x = Activation('relu')(x)
    x = Conv2D(256, (3, 3), padding='same',
               name='block3_conv3', data_format=IMAGE_ORDERING)(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool',
                     data_format=IMAGE_ORDERING)(x)
    levels.append(x)

    # Block 4
    x = Conv2D(512, (3, 3), padding='same',
               name='block4_conv1', data_format=IMAGE_ORDERING)(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same',
               name='block4_conv2', data_format=IMAGE_ORDERING)(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same',
               name='block4_conv3', data_format=IMAGE_ORDERING)(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool',
                     data_format=IMAGE_ORDERING)(x)
    levels.append(x)

    # Block 5
    x = Conv2D(512, (3, 3), padding='same',
               name='block5_conv1', data_format=IMAGE_ORDERING)(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same',
               name='block5_conv2', data_format=IMAGE_ORDERING)(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same',
               name='block5_conv3', data_format=IMAGE_ORDERING)(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool',
                     data_format=IMAGE_ORDERING)(x)

    levels.append(x)

    [f1, f2, f3, f4, f5] = levels

    o = f5

    # Decoder
    o = (Conv2D(4096, (7 , 7 ), padding = 'same', kernel_initializer = 'he_normal', name = "conv6"))(o)
    o = Activation('relu')(o)
    o = Dropout(drop_rate)(o)
    o = (Conv2D(4096, (1 , 1 ), padding = 'same', kernel_initializer = 'he_normal', name = "conv7"))(o)
    o = Activation('relu')(o)
    o = Dropout(drop_rate)(o)

    o = (Conv2D(1, 1, padding='same', kernel_initializer='he_normal', name="scorer1"))(o)
    o = Conv2DTranspose(1, kernel_size=(64,64), padding='same', strides=(32,32), name="Upsample32")(o)
    o = (Conv2D(1, 1, padding='same', kernel_initializer='he_normal', name="output"))(o)

    # Output
    o = Activation('sigmoid')(o)

    model = Model(inputs, o)
    # model.compile(optimizer = Adam(learning_rate = lr), loss = 'binary_crossentropy', metrics = ['accuracy', 'mse'])
    model.compile(optimizer = Adam(learning_rate = lr), loss = bce_dice_loss_weighted, metrics = ['accuracy', iou_metric])
    model.model_name = "fcn_32"
    return model

# %%
# Print model layers and number of parameters
fcn_32().summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 512, 512, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 512, 512, 64)      1792
#
#  activation_77 (Activation)  (None, 512, 512, 64)      0
#
#  block1_conv2 (Conv2D)       (None, 512, 512, 64)      36928
#
#  activation_78 (Activation)  (None, 512, 512, 64)      0
#
#  block1_pool (MaxPooling2D)  (None, 256, 256, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 256, 256, 128)     73856
#
#  activation_79 (Activation)  (None, 256, 256, 128)     0
#
#  block2_conv2 (Conv2D)       (None, 256, 256, 128)     147584
#
#  activation_80 (Activation)  (None, 256, 256, 128)     0
#
#  block2_pool (MaxPooling2D)  (None, 128, 128, 128)     0
#
#  block3_conv1 (Conv2D)       (None, 128, 128, 256)     295168
#
#  activation_81 (Activation)  (None, 128, 128, 256)     0
#
#  block3_conv2 (Conv2D)       (None, 128, 128, 256)     590080
#
#  activation_82 (Activation)  (None, 128, 128, 256)     0
#
#  block3_conv3 (Conv2D)       (None, 128, 128, 256)     590080
#
#  activation_83 (Activation)  (None, 128, 128, 256)     0
#
#  block3_pool (MaxPooling2D)  (None, 64, 64, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 64, 64, 512)       1180160
#
#  activation_84 (Activation)  (None, 64, 64, 512)       0
#
#  block4_conv2 (Conv2D)       (None, 64, 64, 512)       2359808
#
#  activation_85 (Activation)  (None, 64, 64, 512)       0
#
#  block4_conv3 (Conv2D)       (None, 64, 64, 512)       2359808
#
#  activation_86 (Activation)  (None, 64, 64, 512)       0
#
#  block4_pool (MaxPooling2D)  (None, 32, 32, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  activation_87 (Activation)  (None, 32, 32, 512)       0
#
#  block5_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  activation_88 (Activation)  (None, 32, 32, 512)       0
#
#  block5_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  activation_89 (Activation)  (None, 32, 32, 512)       0
#
#  block5_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  conv6 (Conv2D)              (None, 16, 16, 4096)      102764544
#
#  activation_90 (Activation)  (None, 16, 16, 4096)      0
#
#  dropout (Dropout)           (None, 16, 16, 4096)      0
#
#  conv7 (Conv2D)              (None, 16, 16, 4096)      16781312
#
#  activation_91 (Activation)  (None, 16, 16, 4096)      0
#
#  dropout_1 (Dropout)         (None, 16, 16, 4096)      0
#
#  scorer1 (Conv2D)            (None, 16, 16, 1)         4097
#
#  Upsample32 (Conv2DTranspose  (None, 512, 512, 1)      4097
#  )
#
#  output (Conv2D)             (None, 512, 512, 1)       2
#
#  activation_92 (Activation)  (None, 512, 512, 1)       0
#
# =================================================================
# Total params: 134,268,740
# Trainable params: 134,268,740
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## ResUNet

# %%
import tensorflow as tf

def res_block_initial(x, num_filters, kernel_size, strides, name):
    """Residual Unet block layer for first layer
    In the residual unet the first residual block does not contain an
    initial batch normalization and activation so we create this separate
    block for it.
    Args:
        x: tensor, image or image activation
        num_filters: list, contains the number of filters for each subblock
        kernel_size: int, size of the convolutional kernel
        strides: list, contains the stride for each subblock convolution
        name: name of the layer
    Returns:
        x1: tensor, output from residual connection of x and x1
    """

    if len(num_filters) == 1:
        num_filters = [num_filters[0], num_filters[0]]
            
    x1 = tf.keras.layers.Conv2D(filters=num_filters[0], 
                                kernel_size=kernel_size, 
                                strides=strides[0], 
                                padding='same', 
                                kernel_initializer = 'he_normal',
                                name=name+'_1')(x)
    #x1 = tf.keras.layers.BatchNormalization()(x1)
    x1 = tf.keras.layers.Activation('relu')(x1)
    x1 = tf.keras.layers.Conv2D(filters=num_filters[1], 
                                kernel_size=kernel_size,
                                strides=strides[1], 
                                padding='same', 
                                kernel_initializer = 'he_normal',
                                name=name+'_2')(x1)

    x = tf.keras.layers.Conv2D(filters=num_filters[-1],
                                kernel_size=1,
                                strides=1,
                                padding='same',
                                kernel_initializer = 'he_normal',
                                name=name+'_shortcut')(x)
    #x = tf.keras.layers.BatchNormalization()(x)

    x1 = tf.keras.layers.Add()([x, x1])
    
    return x1

def res_block(x, num_filters, kernel_size, strides, name):
    """Residual Unet block layer
    Consists of batch norm and relu, folowed by conv, batch norm and relu and 
    final convolution. The input is then put through 
    Args:
        x: tensor, image or image activation
        num_filters: list, contains the number of filters for each subblock
        kernel_size: int, size of the convolutional kernel
        strides: list, contains the stride for each subblock convolution
        name: name of the layer
    Returns:
        x1: tensor, output from residual connection of x and x1
    """

    if len(num_filters) == 1:
        num_filters = [num_filters[0], num_filters[0]]

    #x1 = tf.keras.layers.BatchNormalization()(x)
    #x1 = tf.keras.layers.Activation('relu')(x1)
    x1 = tf.keras.layers.Activation('relu')(x)
    x1 = tf.keras.layers.Conv2D(filters=num_filters[0], 
                                kernel_size=kernel_size, 
                                strides=strides[0], 
                                padding='same', 
                                kernel_initializer = 'he_normal',
                                name=name+'_1')(x1)
    #x1 = tf.keras.layers.BatchNormalization()(x1)
    x1 = tf.keras.layers.Activation('relu')(x1)
    x1 = tf.keras.layers.Conv2D(filters=num_filters[1], 
                                kernel_size=kernel_size,
                                strides=strides[1], 
                                padding='same', 
                                kernel_initializer = 'he_normal',
                                name=name+'_2')(x1)

    x = tf.keras.layers.Conv2D(filters=num_filters[-1],
                                    kernel_size=1,
                                    strides=strides[0],
                                    padding='same',
                                    kernel_initializer = 'he_normal',
                                    name=name+'_shortcut')(x)
    #x = tf.keras.layers.BatchNormalization()(x)
                                                            
    x1 = tf.keras.layers.Add()([x, x1])

    return x1


def upsample(x, target_size):
    """"Upsampling function, upsamples the feature map
    Deep Residual Unet paper does not describe the upsampling function 
    in detail. Original Unet uses a transpose convolution that downsamples 
    the number of feature maps. In order to restrict the number of 
    parameters here we use a bilinear resampling layer. This results in 
    the concatentation layer concatenting feature maps with n and n/2 
    features as opposed to n/2  and n/2 in the original unet.
    Args:
        x: tensor, feature map
        target_size: size to resize feature map to
    Returns:
        x_resized: tensor, upsampled feature map
    """

    x_resized = tf.keras.layers.Lambda(lambda x: tf.image.resize(x, target_size))(x)

    return x_resized
        
def encoder(x, num_filters, kernel_size):
    """Unet encoder
    Args:
        x: tensor, output from previous layer
        num_filters: list, number of filters for each decoder layer
        kernel_size: int, size of the convolutional kernel
    Returns:
        encoder_output: list, output from all encoder layers
    """

    x = res_block_initial(x, [num_filters[0]], kernel_size, strides=[1,1], name='layer1')

    encoder_output = [x]
    for i in range(1, len(num_filters)):
        layer = 'encoder_layer' + str(i)
        x = res_block(x, [num_filters[i]], kernel_size, strides=[2,1], name=layer)
        encoder_output.append(x)

    return encoder_output

def decoder(x, encoder_output, num_filters, kernel_size):
    """Unet decoder
    Args:
        x: tensor, output from previous layer
        encoder_output: list, output from all previous encoder layers
        num_filters: list, number of filters for each decoder layer
        kernel_size: int, size of the convolutional kernel
    Returns:
        x: tensor, output from last layer of decoder
    """

    for i in range(1, len(num_filters) + 1):
        layer = 'decoder_layer' + str(i)
        target_size = encoder_output[-i].shape[1:3]
        x = upsample(x, target_size)
        x = tf.keras.layers.Concatenate(axis=-1)([x, encoder_output[-i]])
        x = res_block(x, [num_filters[-i]], kernel_size, strides=[1,1], name=layer)

    return x


def res_unet(input_size, num_filters, kernel_size, num_channels, num_classes, lr = 0.0001, out_layer = 'sigmoid', lossfunc='binary_crossentropy', num_out=1):
    """Residual Unet
    Function that generates a residual unet
    Args:
        input_size: int, dimension of the input image
        num_layers: int, number of layers in the encoder half, excludes bridge
        num_filters: list, number of filters for each encoder layer
        kernel_size: size of the kernel, applied to all convolutions
        num_channels: int, number of channels for the input image
        num_classes: int, number of output classes for the output
    Returns:
        model: tensorflow keras model for residual unet architecture
    """

    x = tf.keras.Input(shape=[input_size, input_size, num_channels])

    encoder_output = encoder(x, num_filters, kernel_size)

    # bridge layer, number of filters is double that of the last encoder layer
    bridge = res_block(encoder_output[-1], [num_filters[-1]*2], kernel_size, 
                        strides=[2,1], name='bridge')

    decoder_output = decoder(bridge, encoder_output, num_filters, kernel_size)

    output = tf.keras.layers.Conv2D(num_classes, 
                                    kernel_size, 
                                    strides=1, 
                                    padding='same', 
                                    kernel_initializer = 'he_normal',
                                    name='output')(decoder_output)

    output = Activation(out_layer)(output)

    model = tf.keras.Model(x, output)
    # model.compile(optimizer = Adam(learning_rate = lr), loss = 'binary_crossentropy', metrics = ['accuracy', 'mse'])
    model.compile(optimizer = Adam(learning_rate = lr), loss = bce_dice_loss_weighted, metrics = ['accuracy', iou_metric])
    return model

# %%
res_unet(512, [64, 128, 256, 512], 3, 3, 1).summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  layer1_1 (Conv2D)              (None, 512, 512, 64  1792        ['input_5[0][0]']
#                                 )
#
#  activation_93 (Activation)     (None, 512, 512, 64  0           ['layer1_1[0][0]']
#                                 )
#
#  layer1_shortcut (Conv2D)       (None, 512, 512, 64  256         ['input_5[0][0]']
#                                 )
#
#  layer1_2 (Conv2D)              (None, 512, 512, 64  36928       ['activation_93[0][0]']
#                                 )
#
#  add_8 (Add)                    (None, 512, 512, 64  0           ['layer1_shortcut[0][0]',
#                                 )                                 'layer1_2[0][0]']
#
#  activation_94 (Activation)     (None, 512, 512, 64  0           ['add_8[0][0]']
#                                 )
#
#  encoder_layer1_1 (Conv2D)      (None, 256, 256, 12  73856       ['activation_94[0][0]']
#                                 8)
#
#  activation_95 (Activation)     (None, 256, 256, 12  0           ['encoder_layer1_1[0][0]']
#                                 8)
#
#  encoder_layer1_shortcut (Conv2  (None, 256, 256, 12  8320       ['add_8[0][0]']
#  D)                             8)
#
#  encoder_layer1_2 (Conv2D)      (None, 256, 256, 12  147584      ['activation_95[0][0]']
#                                 8)
#
#  add_9 (Add)                    (None, 256, 256, 12  0           ['encoder_layer1_shortcut[0][0]',
#                                 8)                                'encoder_layer1_2[0][0]']
#
#  activation_96 (Activation)     (None, 256, 256, 12  0           ['add_9[0][0]']
#                                 8)
#
#  encoder_layer2_1 (Conv2D)      (None, 128, 128, 25  295168      ['activation_96[0][0]']
#                                 6)
#
#  activation_97 (Activation)     (None, 128, 128, 25  0           ['encoder_layer2_1[0][0]']
#                                 6)
#
#  encoder_layer2_shortcut (Conv2  (None, 128, 128, 25  33024      ['add_9[0][0]']
#  D)                             6)
#
#  encoder_layer2_2 (Conv2D)      (None, 128, 128, 25  590080      ['activation_97[0][0]']
#                                 6)
#
#  add_10 (Add)                   (None, 128, 128, 25  0           ['encoder_layer2_shortcut[0][0]',
#                                 6)                                'encoder_layer2_2[0][0]']
#
#  activation_98 (Activation)     (None, 128, 128, 25  0           ['add_10[0][0]']
#                                 6)
#
#  encoder_layer3_1 (Conv2D)      (None, 64, 64, 512)  1180160     ['activation_98[0][0]']
#
#  activation_99 (Activation)     (None, 64, 64, 512)  0           ['encoder_layer3_1[0][0]']
#
#  encoder_layer3_shortcut (Conv2  (None, 64, 64, 512)  131584     ['add_10[0][0]']
#  D)
#
#  encoder_layer3_2 (Conv2D)      (None, 64, 64, 512)  2359808     ['activation_99[0][0]']
#
#  add_11 (Add)                   (None, 64, 64, 512)  0           ['encoder_layer3_shortcut[0][0]',
#                                                                   'encoder_layer3_2[0][0]']
#
#  activation_100 (Activation)    (None, 64, 64, 512)  0           ['add_11[0][0]']
#
#  bridge_1 (Conv2D)              (None, 32, 32, 1024  4719616     ['activation_100[0][0]']
#                                 )
#
#  activation_101 (Activation)    (None, 32, 32, 1024  0           ['bridge_1[0][0]']
#                                 )
#
#  bridge_shortcut (Conv2D)       (None, 32, 32, 1024  525312      ['add_11[0][0]']
#                                 )
#
#  bridge_2 (Conv2D)              (None, 32, 32, 1024  9438208     ['activation_101[0][0]']
#                                 )
#
#  add_12 (Add)                   (None, 32, 32, 1024  0           ['bridge_shortcut[0][0]',
#                                 )                                 'bridge_2[0][0]']
#
#  lambda (Lambda)                (None, 64, 64, 1024  0           ['add_12[0][0]']
#                                 )
#
#  concatenate_8 (Concatenate)    (None, 64, 64, 1536  0           ['lambda[0][0]',
#                                 )                                 'add_11[0][0]']
#
#  activation_102 (Activation)    (None, 64, 64, 1536  0           ['concatenate_8[0][0]']
#                                 )
#
#  decoder_layer1_1 (Conv2D)      (None, 64, 64, 512)  7078400     ['activation_102[0][0]']
#
#  activation_103 (Activation)    (None, 64, 64, 512)  0           ['decoder_layer1_1[0][0]']
#
#  decoder_layer1_shortcut (Conv2  (None, 64, 64, 512)  786944     ['concatenate_8[0][0]']
#  D)
#
#  decoder_layer1_2 (Conv2D)      (None, 64, 64, 512)  2359808     ['activation_103[0][0]']
#
#  add_13 (Add)                   (None, 64, 64, 512)  0           ['decoder_layer1_shortcut[0][0]',
#                                                                   'decoder_layer1_2[0][0]']
#
#  lambda_1 (Lambda)              (None, 128, 128, 51  0           ['add_13[0][0]']
#                                 2)
#
#  concatenate_9 (Concatenate)    (None, 128, 128, 76  0           ['lambda_1[0][0]',
#                                 8)                                'add_10[0][0]']
#
#  activation_104 (Activation)    (None, 128, 128, 76  0           ['concatenate_9[0][0]']
#                                 8)
#
#  decoder_layer2_1 (Conv2D)      (None, 128, 128, 25  1769728     ['activation_104[0][0]']
#                                 6)
#
#  activation_105 (Activation)    (None, 128, 128, 25  0           ['decoder_layer2_1[0][0]']
#                                 6)
#
#  decoder_layer2_shortcut (Conv2  (None, 128, 128, 25  196864     ['concatenate_9[0][0]']
#  D)                             6)
#
#  decoder_layer2_2 (Conv2D)      (None, 128, 128, 25  590080      ['activation_105[0][0]']
#                                 6)
#
#  add_14 (Add)                   (None, 128, 128, 25  0           ['decoder_layer2_shortcut[0][0]',
#                                 6)                                'decoder_layer2_2[0][0]']
#
#  lambda_2 (Lambda)              (None, 256, 256, 25  0           ['add_14[0][0]']
#                                 6)
#
#  concatenate_10 (Concatenate)   (None, 256, 256, 38  0           ['lambda_2[0][0]',
#                                 4)                                'add_9[0][0]']
#
#  activation_106 (Activation)    (None, 256, 256, 38  0           ['concatenate_10[0][0]']
#                                 4)
#
#  decoder_layer3_1 (Conv2D)      (None, 256, 256, 12  442496      ['activation_106[0][0]']
#                                 8)
#
#  activation_107 (Activation)    (None, 256, 256, 12  0           ['decoder_layer3_1[0][0]']
#                                 8)
#
#  decoder_layer3_shortcut (Conv2  (None, 256, 256, 12  49280      ['concatenate_10[0][0]']
#  D)                             8)
#
#  decoder_layer3_2 (Conv2D)      (None, 256, 256, 12  147584      ['activation_107[0][0]']
#                                 8)
#
#  add_15 (Add)                   (None, 256, 256, 12  0           ['decoder_layer3_shortcut[0][0]',
#                                 8)                                'decoder_layer3_2[0][0]']
#
#  lambda_3 (Lambda)              (None, 512, 512, 12  0           ['add_15[0][0]']
#                                 8)
#
#  concatenate_11 (Concatenate)   (None, 512, 512, 19  0           ['lambda_3[0][0]',
#                                 2)                                'add_8[0][0]']
#
#  activation_108 (Activation)    (None, 512, 512, 19  0           ['concatenate_11[0][0]']
#                                 2)
#
#  decoder_layer4_1 (Conv2D)      (None, 512, 512, 64  110656      ['activation_108[0][0]']
#                                 )
#
#  activation_109 (Activation)    (None, 512, 512, 64  0           ['decoder_layer4_1[0][0]']
#                                 )
#
#  decoder_layer4_shortcut (Conv2  (None, 512, 512, 64  12352      ['concatenate_11[0][0]']
#  D)                             )
#
#  decoder_layer4_2 (Conv2D)      (None, 512, 512, 64  36928       ['activation_109[0][0]']
#                                 )
#
#  add_16 (Add)                   (None, 512, 512, 64  0           ['decoder_layer4_shortcut[0][0]',
#                                 )                                 'decoder_layer4_2[0][0]']
#
#  output (Conv2D)                (None, 512, 512, 1)  577         ['add_16[0][0]']
#
#  activation_110 (Activation)    (None, 512, 512, 1)  0           ['output[0][0]']
#
# ==================================================================================================
# Total params: 33,123,393
# Trainable params: 33,123,393
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Train on New feature data

# %%
# Train U-Net with generator
model_unet = UNet(input_size=(512,512,3), lr=0.0001)
save_model = ModelCheckpoint('unet-3d.hdf5', monitor='val_iou_metric',verbose=1, save_best_only=True, mode='max')
train = trainGenerator(1, t_images, t_masks, data_gen_args, save_to_dir=None)

model_unet.fit(train, steps_per_epoch = 230, epochs=40, validation_data = validation_Nepal_landslide_dataset, callbacks=[save_model, reduce_lr])
# Out:
# Epoch 1/40
# 2025-12-10 04:18:01.796239: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2025-12-10 04:18:05.059276: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 230/230 [==============================] - ETA: 0s - loss: 0.4671 - accuracy: 0.9072 - iou_metric: 0.0733
# Epoch 1: val_iou_metric improved from -inf to 0.11124, saving model to unet-3d.hdf5
# 230/230 [==============================] - 32s 90ms/step - loss: 0.4671 - accuracy: 0.9072 - iou_metric: 0.0733 - val_loss: 0.4381 - val_accuracy: 0.9795 - val_iou_metric: 0.1112 - lr: 1.0000e-04
# Epoch 2/40
# 230/230 [==============================] - ETA: 0s - loss: 0.4152 - accuracy: 0.9539 - iou_metric: 0.1445
# Epoch 2: val_iou_metric improved from 0.11124 to 0.22976, saving model to unet-3d.hdf5
# 230/230 [==============================] - 19s 82ms/step - loss: 0.4152 - accuracy: 0.9539 - iou_metric: 0.1445 - val_loss: 0.3440 - val_accuracy: 0.9699 - val_iou_metric: 0.2298 - lr: 1.0000e-04
# Epoch 3/40
# 230/230 [==============================] - ETA: 0s - loss: 0.3597 - accuracy: 0.9802 - iou_metric: 0.2187
# Epoch 3: val_iou_metric improved from 0.22976 to 0.35063, saving model to unet-3d.hdf5
# 230/230 [==============================] - 19s 83ms/step - loss: 0.3597 - accuracy: 0.9802 - iou_metric: 0.2187 - val_loss: 0.2704 - val_accuracy: 0.9861 - val_iou_metric: 0.3506 - lr: 1.0000e-04
# Epoch 4/40
# 230/230 [==============================] - ETA: 0s - loss: 0.3518 - accuracy: 0.9760 - iou_metric: 0.2327
# Epoch 4: val_iou_metric did not improve from 0.35063
# 230/230 [==============================] - 18s 79ms/step - loss: 0.3518 - accuracy: 0.9760 - iou_metric: 0.2327 - val_loss: 0.2717 - val_accuracy: 0.9883 - val_iou_metric: 0.3504 - lr: 1.0000e-04
# Epoch 5/40
# 230/230 [==============================] - ETA: 0s - loss: 0.3364 - accuracy: 0.9808 - iou_metric: 0.2575
# Epoch 5: val_iou_metric improved from 0.35063 to 0.38314, saving model to unet-3d.hdf5
# 230/230 [==============================] - 19s 83ms/step - loss: 0.3364 - accuracy: 0.9808 - iou_metric: 0.2575 - val_loss: 0.2474 - val_accuracy: 0.9853 - val_iou_metric: 0.3831 - lr: 1.0000e-04
# Epoch 6/40
# 230/230 [==============================] - ETA: 0s - loss: 0.3379 - accuracy: 0.9817 - iou_metric: 0.2536
# Epoch 6: val_iou_metric did not improve from 0.38314
# 230/230 [==============================] - 18s 79ms/step - loss: 0.3379 - accuracy: 0.9817 - iou_metric: 0.2536 - val_loss: 0.2521 - val_accuracy: 0.9847 - val_iou_metric: 0.3712 - lr: 1.0000e-04
# Epoch 7/40
# 230/230 [==============================] - ETA: 0s - loss: 0.3309 - accuracy: 0.9827 - iou_metric: 0.2585
# Epoch 7: val_iou_metric did not improve from 0.38314
# 230/230 [==============================] - 19s 81ms/step - loss: 0.3309 - accuracy: 0.9827 - iou_metric: 0.2585 - val_loss: 0.2472 - val_accuracy: 0.9851 - val_iou_metric: 0.3805 - lr: 1.0000e-04
# Epoch 8/40
# 230/230 [==============================] - ETA: 0s - loss: 0.3381 - accuracy: 0.9817 - iou_metric: 0.2510
# Epoch 8: val_iou_metric improved from 0.38314 to 0.40135, saving model to unet-3d.hdf5
# 230/230 [==============================] - 19s 83ms/step - loss: 0.3381 - accuracy: 0.9817 - iou_metric: 0.2510 - val_loss: 0.2421 - val_accuracy: 0.9871 - val_iou_metric: 0.4013 - lr: 1.0000e-04
# Epoch 9/40
# 230/230 [==============================] - ETA: 0s - loss: 0.3135 - accuracy: 0.9851 - iou_metric: 0.2904
# Epoch 9: val_iou_metric did not improve from 0.40135
# 230/230 [==============================] - 19s 84ms/step - loss: 0.3135 - accuracy: 0.9851 - iou_metric: 0.2904 - val_loss: 0.2640 - val_accuracy: 0.9897 - val_iou_metric: 0.3670 - lr: 1.0000e-04
# Epoch 10/40
# 230/230 [==============================] - ETA: 0s - loss: 0.3123 - accuracy: 0.9865 - iou_metric: 0.2939
# Epoch 10: val_iou_metric did not improve from 0.40135
# 230/230 [==============================] - 20s 86ms/step - loss: 0.3123 - accuracy: 0.9865 - iou_metric: 0.2939 - val_loss: 0.3036 - val_accuracy: 0.9914 - val_iou_metric: 0.3104 - lr: 1.0000e-04
# Epoch 11/40
# 230/230 [==============================] - ETA: 0s - loss: 0.3106 - accuracy: 0.9865 - iou_metric: 0.2969
# Epoch 11: val_iou_metric did not improve from 0.40135
# 230/230 [==============================] - 18s 78ms/step - loss: 0.3106 - accuracy: 0.9865 - iou_metric: 0.2969 - val_loss: 0.2379 - val_accuracy: 0.9829 - val_iou_metric: 0.4006 - lr: 1.0000e-04
# Epoch 12/40
# 230/230 [==============================] - ETA: 0s - loss: 0.3128 - accuracy: 0.9856 - iou_metric: 0.2910
# Epoch 12: val_iou_metric did not improve from 0.40135
# 230/230 [==============================] - 19s 81ms/step - loss: 0.3128 - accuracy: 0.9856 - iou_metric: 0.2910 - val_loss: 0.2496 - val_accuracy: 0.9828 - val_iou_metric: 0.3768 - lr: 1.0000e-04
# Epoch 13/40
# 230/230 [==============================] - ETA: 0s - loss: 0.3050 - accuracy: 0.9866 - iou_metric: 0.3008
# Epoch 13: val_iou_metric did not improve from 0.40135
# 230/230 [==============================] - 19s 81ms/step - loss: 0.3050 - accuracy: 0.9866 - iou_metric: 0.3008 - val_loss: 0.2528 - val_accuracy: 0.9905 - val_iou_metric: 0.3863 - lr: 1.0000e-04
# Epoch 14/40
# 230/230 [==============================] - ETA: 0s - loss: 0.3064 - accuracy: 0.9863 - iou_metric: 0.3019
# Epoch 14: val_iou_metric did not improve from 0.40135
# 230/230 [==============================] - 18s 77ms/step - loss: 0.3064 - accuracy: 0.9863 - iou_metric: 0.3019 - val_loss: 0.2498 - val_accuracy: 0.9860 - val_iou_metric: 0.3766 - lr: 1.0000e-04
# Epoch 15/40
# 230/230 [==============================] - ETA: 0s - loss: 0.3034 - accuracy: 0.9850 - iou_metric: 0.3043
# Epoch 15: val_iou_metric improved from 0.40135 to 0.42443, saving model to unet-3d.hdf5
# 230/230 [==============================] - 20s 85ms/step - loss: 0.3034 - accuracy: 0.9850 - iou_metric: 0.3043 - val_loss: 0.2250 - val_accuracy: 0.9884 - val_iou_metric: 0.4244 - lr: 1.0000e-04
# Epoch 16/40
# 230/230 [==============================] - ETA: 0s - loss: 0.2948 - accuracy: 0.9885 - iou_metric: 0.3197
# Epoch 16: val_iou_metric did not improve from 0.42443
# 230/230 [==============================] - 18s 79ms/step - loss: 0.2948 - accuracy: 0.9885 - iou_metric: 0.3197 - val_loss: 0.2303 - val_accuracy: 0.9914 - val_iou_metric: 0.4178 - lr: 1.0000e-04
# Epoch 17/40
# 230/230 [==============================] - ETA: 0s - loss: 0.2976 - accuracy: 0.9886 - iou_metric: 0.3122
# Epoch 17: val_iou_metric did not improve from 0.42443
# 230/230 [==============================] - 18s 78ms/step - loss: 0.2976 - accuracy: 0.9886 - iou_metric: 0.3122 - val_loss: 0.2299 - val_accuracy: 0.9865 - val_iou_metric: 0.4169 - lr: 1.0000e-04
# Epoch 18/40
# 230/230 [==============================] - ETA: 0s - loss: 0.2892 - accuracy: 0.9875 - iou_metric: 0.3255
# Epoch 18: val_iou_metric improved from 0.42443 to 0.44793, saving model to unet-3d.hdf5
# 230/230 [==============================] - 19s 82ms/step - loss: 0.2892 - accuracy: 0.9875 - iou_metric: 0.3255 - val_loss: 0.2110 - val_accuracy: 0.9902 - val_iou_metric: 0.4479 - lr: 1.0000e-04
# Epoch 19/40
# 230/230 [==============================] - ETA: 0s - loss: 0.2960 - accuracy: 0.9884 - iou_metric: 0.3098
# Epoch 19: val_iou_metric did not improve from 0.44793
# 230/230 [==============================] - 18s 77ms/step - loss: 0.2960 - accuracy: 0.9884 - iou_metric: 0.3098 - val_loss: 0.2359 - val_accuracy: 0.9857 - val_iou_metric: 0.4045 - lr: 1.0000e-04
# Epoch 20/40
# 230/230 [==============================] - ETA: 0s - loss: 0.3082 - accuracy: 0.9854 - iou_metric: 0.2940
# Epoch 20: val_iou_metric did not improve from 0.44793
# 230/230 [==============================] - 18s 80ms/step - loss: 0.3082 - accuracy: 0.9854 - iou_metric: 0.2940 - val_loss: 0.2404 - val_accuracy: 0.9867 - val_iou_metric: 0.3908 - lr: 1.0000e-04
# Epoch 21/40
# 230/230 [==============================] - ETA: 0s - loss: 0.3001 - accuracy: 0.9878 - iou_metric: 0.3104
# Epoch 21: val_iou_metric did not improve from 0.44793
# 230/230 [==============================] - 18s 78ms/step - loss: 0.3001 - accuracy: 0.9878 - iou_metric: 0.3104 - val_loss: 0.2332 - val_accuracy: 0.9916 - val_iou_metric: 0.4178 - lr: 1.0000e-04
# Epoch 22/40
# 230/230 [==============================] - ETA: 0s - loss: 0.2850 - accuracy: 0.9882 - iou_metric: 0.3304
# Epoch 22: val_iou_metric improved from 0.44793 to 0.45684, saving model to unet-3d.hdf5
# 230/230 [==============================] - 19s 81ms/step - loss: 0.2850 - accuracy: 0.9882 - iou_metric: 0.3304 - val_loss: 0.2095 - val_accuracy: 0.9906 - val_iou_metric: 0.4568 - lr: 1.0000e-04
# Epoch 23/40
# 230/230 [==============================] - ETA: 0s - loss: 0.2757 - accuracy: 0.9900 - iou_metric: 0.3472
# Epoch 23: val_iou_metric did not improve from 0.45684
# 230/230 [==============================] - 18s 78ms/step - loss: 0.2757 - accuracy: 0.9900 - iou_metric: 0.3472 - val_loss: 0.2332 - val_accuracy: 0.9923 - val_iou_metric: 0.4219 - lr: 1.0000e-04
# Epoch 24/40
# 230/230 [==============================] - ETA: 0s - loss: 0.2939 - accuracy: 0.9884 - iou_metric: 0.3170
# Epoch 24: val_iou_metric did not improve from 0.45684
# 230/230 [==============================] - 18s 80ms/step - loss: 0.2939 - accuracy: 0.9884 - iou_metric: 0.3170 - val_loss: 0.2124 - val_accuracy: 0.9915 - val_iou_metric: 0.4494 - lr: 1.0000e-04
# Epoch 25/40
# 230/230 [==============================] - ETA: 0s - loss: 0.2792 - accuracy: 0.9890 - iou_metric: 0.3402
# Epoch 25: val_iou_metric did not improve from 0.45684
# 230/230 [==============================] - 18s 79ms/step - loss: 0.2792 - accuracy: 0.9890 - iou_metric: 0.3402 - val_loss: 0.2347 - val_accuracy: 0.9867 - val_iou_metric: 0.4014 - lr: 1.0000e-04
# Epoch 26/40
# 230/230 [==============================] - ETA: 0s - loss: 0.2720 - accuracy: 0.9903 - iou_metric: 0.3503
# Epoch 26: val_iou_metric did not improve from 0.45684
# 230/230 [==============================] - 19s 82ms/step - loss: 0.2720 - accuracy: 0.9903 - iou_metric: 0.3503 - val_loss: 0.2149 - val_accuracy: 0.9895 - val_iou_metric: 0.4464 - lr: 1.0000e-04
# Epoch 27/40
# 230/230 [==============================] - ETA: 0s - loss: 0.2775 - accuracy: 0.9897 - iou_metric: 0.3454
# Epoch 27: val_iou_metric did not improve from 0.45684
# 230/230 [==============================] - 19s 81ms/step - loss: 0.2775 - accuracy: 0.9897 - iou_metric: 0.3454 - val_loss: 0.2178 - val_accuracy: 0.9902 - val_iou_metric: 0.4380 - lr: 1.0000e-04
# Epoch 28/40
# 230/230 [==============================] - ETA: 0s - loss: 0.2799 - accuracy: 0.9904 - iou_metric: 0.3430
# Epoch 28: val_iou_metric did not improve from 0.45684
# 230/230 [==============================] - 18s 79ms/step - loss: 0.2799 - accuracy: 0.9904 - iou_metric: 0.3430 - val_loss: 0.3626 - val_accuracy: 0.9917 - val_iou_metric: 0.2322 - lr: 1.0000e-04
# Epoch 29/40
# 230/230 [==============================] - ETA: 0s - loss: 0.2794 - accuracy: 0.9902 - iou_metric: 0.3414
# Epoch 29: val_iou_metric did not improve from 0.45684
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 230/230 [==============================] - 18s 77ms/step - loss: 0.2794 - accuracy: 0.9902 - iou_metric: 0.3414 - val_loss: 0.2156 - val_accuracy: 0.9901 - val_iou_metric: 0.4422 - lr: 1.0000e-04
# Epoch 30/40
# 230/230 [==============================] - ETA: 0s - loss: 0.2751 - accuracy: 0.9896 - iou_metric: 0.3471
# Epoch 30: val_iou_metric did not improve from 0.45684
# 230/230 [==============================] - 19s 82ms/step - loss: 0.2751 - accuracy: 0.9896 - iou_metric: 0.3471 - val_loss: 0.2113 - val_accuracy: 0.9892 - val_iou_metric: 0.4489 - lr: 5.0000e-05
# Epoch 31/40
# 230/230 [==============================] - ETA: 0s - loss: 0.2693 - accuracy: 0.9901 - iou_metric: 0.3562
# Epoch 31: val_iou_metric improved from 0.45684 to 0.46493, saving model to unet-3d.hdf5
# 230/230 [==============================] - 19s 84ms/step - loss: 0.2693 - accuracy: 0.9901 - iou_metric: 0.3562 - val_loss: 0.2031 - val_accuracy: 0.9908 - val_iou_metric: 0.4649 - lr: 5.0000e-05
# Epoch 32/40
# 230/230 [==============================] - ETA: 0s - loss: 0.2632 - accuracy: 0.9908 - iou_metric: 0.3644
# Epoch 32: val_iou_metric did not improve from 0.46493
# 230/230 [==============================] - 17s 76ms/step - loss: 0.2632 - accuracy: 0.9908 - iou_metric: 0.3644 - val_loss: 0.2109 - val_accuracy: 0.9910 - val_iou_metric: 0.4513 - lr: 5.0000e-05
# Epoch 33/40
# 230/230 [==============================] - ETA: 0s - loss: 0.2629 - accuracy: 0.9908 - iou_metric: 0.3682
# Epoch 33: val_iou_metric improved from 0.46493 to 0.47128, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 80ms/step - loss: 0.2629 - accuracy: 0.9908 - iou_metric: 0.3682 - val_loss: 0.1999 - val_accuracy: 0.9913 - val_iou_metric: 0.4713 - lr: 5.0000e-05
# Epoch 34/40
# 230/230 [==============================] - ETA: 0s - loss: 0.2503 - accuracy: 0.9914 - iou_metric: 0.3895
# Epoch 34: val_iou_metric did not improve from 0.47128
# 230/230 [==============================] - 18s 77ms/step - loss: 0.2503 - accuracy: 0.9914 - iou_metric: 0.3895 - val_loss: 0.2069 - val_accuracy: 0.9898 - val_iou_metric: 0.4561 - lr: 5.0000e-05
# Epoch 35/40
# 230/230 [==============================] - ETA: 0s - loss: 0.2623 - accuracy: 0.9903 - iou_metric: 0.3653
# Epoch 35: val_iou_metric did not improve from 0.47128
# 230/230 [==============================] - 19s 81ms/step - loss: 0.2623 - accuracy: 0.9903 - iou_metric: 0.3653 - val_loss: 0.2048 - val_accuracy: 0.9897 - val_iou_metric: 0.4562 - lr: 5.0000e-05
# Epoch 36/40
# 230/230 [==============================] - ETA: 0s - loss: 0.2599 - accuracy: 0.9906 - iou_metric: 0.3743
# Epoch 36: val_iou_metric did not improve from 0.47128
# 230/230 [==============================] - 18s 79ms/step - loss: 0.2599 - accuracy: 0.9906 - iou_metric: 0.3743 - val_loss: 0.2176 - val_accuracy: 0.9887 - val_iou_metric: 0.4306 - lr: 5.0000e-05
# Epoch 37/40
# 230/230 [==============================] - ETA: 0s - loss: 0.2634 - accuracy: 0.9898 - iou_metric: 0.3656
# Epoch 37: val_iou_metric improved from 0.47128 to 0.48545, saving model to unet-3d.hdf5
# 230/230 [==============================] - 19s 82ms/step - loss: 0.2634 - accuracy: 0.9898 - iou_metric: 0.3656 - val_loss: 0.1920 - val_accuracy: 0.9914 - val_iou_metric: 0.4855 - lr: 5.0000e-05
# Epoch 38/40
# 230/230 [==============================] - ETA: 0s - loss: 0.2540 - accuracy: 0.9910 - iou_metric: 0.3823
# Epoch 38: val_iou_metric did not improve from 0.48545
# 230/230 [==============================] - 18s 78ms/step - loss: 0.2540 - accuracy: 0.9910 - iou_metric: 0.3823 - val_loss: 0.2016 - val_accuracy: 0.9909 - val_iou_metric: 0.4654 - lr: 5.0000e-05
# Epoch 39/40
# 230/230 [==============================] - ETA: 0s - loss: 0.2594 - accuracy: 0.9906 - iou_metric: 0.3709
# Epoch 39: val_iou_metric did not improve from 0.48545
# 230/230 [==============================] - 18s 78ms/step - loss: 0.2594 - accuracy: 0.9906 - iou_metric: 0.3709 - val_loss: 0.1929 - val_accuracy: 0.9919 - val_iou_metric: 0.4836 - lr: 5.0000e-05
# Epoch 40/40
# 230/230 [==============================] - ETA: 0s - loss: 0.2589 - accuracy: 0.9908 - iou_metric: 0.3746
# Epoch 40: val_iou_metric did not improve from 0.48545
# 230/230 [==============================] - 18s 80ms/step - loss: 0.2589 - accuracy: 0.9908 - iou_metric: 0.3746 - val_loss: 0.2017 - val_accuracy: 0.9918 - val_iou_metric: 0.4711 - lr: 5.0000e-05

# %%
# Save model training history
np.save('unet-3d-history.npy',model_unet.history.history)

# %%
# Plot accuracy and loss 

## Accuracy
plt.plot(model_unet.history.history['accuracy'])
plt.plot(model_unet.history.history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.show()

## Loss
plt.plot(model_unet.history.history['loss'])
plt.plot(model_unet.history.history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')

# %% [markdown]
# ## Attention U-Net

# %%
# Train Attention U-Net with generator
model_attention_unet = UNetAM(lr=0.0001, filter_base=16)
save_model = ModelCheckpoint('unet-3d.hdf5', monitor='val_iou_metric',verbose=1, save_best_only=True, mode='max' )
train = trainGenerator(1, t_images, t_masks, data_gen_args, save_to_dir=None)

model_attention_unet.fit(train, steps_per_epoch = 230, epochs=60, validation_data = validation_Nepal_landslide_dataset, callbacks=[save_model, reduce_lr])
# Out:
# Epoch 1/60
# 230/230 [==============================] - ETA: 0s - loss: 0.4905 - accuracy: 0.9840 - iou_metric: 0.0099
# Epoch 1: val_iou_metric improved from -inf to 0.09367, saving model to unet-3d.hdf5
# 230/230 [==============================] - 22s 83ms/step - loss: 0.4905 - accuracy: 0.9840 - iou_metric: 0.0099 - val_loss: 0.4300 - val_accuracy: 0.9834 - val_iou_metric: 0.0937 - lr: 1.0000e-04
# Epoch 2/60
# 230/230 [==============================] - ETA: 0s - loss: 0.4404 - accuracy: 0.9355 - iou_metric: 0.1041
# Epoch 2: val_iou_metric improved from 0.09367 to 0.17128, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 79ms/step - loss: 0.4404 - accuracy: 0.9355 - iou_metric: 0.1041 - val_loss: 0.3838 - val_accuracy: 0.9394 - val_iou_metric: 0.1713 - lr: 1.0000e-04
# Epoch 3/60
# 230/230 [==============================] - ETA: 0s - loss: 0.3933 - accuracy: 0.9577 - iou_metric: 0.1736
# Epoch 3: val_iou_metric improved from 0.17128 to 0.28880, saving model to unet-3d.hdf5
# 230/230 [==============================] - 17s 75ms/step - loss: 0.3933 - accuracy: 0.9577 - iou_metric: 0.1736 - val_loss: 0.3022 - val_accuracy: 0.9781 - val_iou_metric: 0.2888 - lr: 1.0000e-04
# Epoch 4/60
# 230/230 [==============================] - ETA: 0s - loss: 0.3434 - accuracy: 0.9777 - iou_metric: 0.2413
# Epoch 4: val_iou_metric improved from 0.28880 to 0.35542, saving model to unet-3d.hdf5
# 230/230 [==============================] - 17s 72ms/step - loss: 0.3434 - accuracy: 0.9777 - iou_metric: 0.2413 - val_loss: 0.2710 - val_accuracy: 0.9898 - val_iou_metric: 0.3554 - lr: 1.0000e-04
# Epoch 5/60
# 230/230 [==============================] - ETA: 0s - loss: 0.3429 - accuracy: 0.9797 - iou_metric: 0.2432
# Epoch 5: val_iou_metric improved from 0.35542 to 0.36994, saving model to unet-3d.hdf5
# 230/230 [==============================] - 19s 81ms/step - loss: 0.3429 - accuracy: 0.9797 - iou_metric: 0.2432 - val_loss: 0.2596 - val_accuracy: 0.9874 - val_iou_metric: 0.3699 - lr: 1.0000e-04
# Epoch 6/60
# 230/230 [==============================] - ETA: 0s - loss: 0.3237 - accuracy: 0.9863 - iou_metric: 0.2697
# Epoch 6: val_iou_metric improved from 0.36994 to 0.38313, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 79ms/step - loss: 0.3237 - accuracy: 0.9863 - iou_metric: 0.2697 - val_loss: 0.2496 - val_accuracy: 0.9879 - val_iou_metric: 0.3831 - lr: 1.0000e-04
# Epoch 7/60
# 230/230 [==============================] - ETA: 0s - loss: 0.3205 - accuracy: 0.9869 - iou_metric: 0.2726
# Epoch 7: val_iou_metric did not improve from 0.38313
# 230/230 [==============================] - 18s 80ms/step - loss: 0.3205 - accuracy: 0.9869 - iou_metric: 0.2726 - val_loss: 0.2521 - val_accuracy: 0.9892 - val_iou_metric: 0.3775 - lr: 1.0000e-04
# Epoch 8/60
# 230/230 [==============================] - ETA: 0s - loss: 0.3222 - accuracy: 0.9839 - iou_metric: 0.2766
# Epoch 8: val_iou_metric did not improve from 0.38313
# 230/230 [==============================] - 18s 79ms/step - loss: 0.3222 - accuracy: 0.9839 - iou_metric: 0.2766 - val_loss: 0.2647 - val_accuracy: 0.9905 - val_iou_metric: 0.3670 - lr: 1.0000e-04
# Epoch 9/60
# 230/230 [==============================] - ETA: 0s - loss: 0.3207 - accuracy: 0.9861 - iou_metric: 0.2823
# Epoch 9: val_iou_metric improved from 0.38313 to 0.40556, saving model to unet-3d.hdf5
# 230/230 [==============================] - 17s 73ms/step - loss: 0.3207 - accuracy: 0.9861 - iou_metric: 0.2823 - val_loss: 0.2406 - val_accuracy: 0.9895 - val_iou_metric: 0.4056 - lr: 1.0000e-04
# Epoch 10/60
# 230/230 [==============================] - ETA: 0s - loss: 0.3120 - accuracy: 0.9860 - iou_metric: 0.2883
# Epoch 10: val_iou_metric did not improve from 0.40556
# 230/230 [==============================] - 16s 68ms/step - loss: 0.3120 - accuracy: 0.9860 - iou_metric: 0.2883 - val_loss: 0.2744 - val_accuracy: 0.9912 - val_iou_metric: 0.3549 - lr: 1.0000e-04
# Epoch 11/60
# 230/230 [==============================] - ETA: 0s - loss: 0.3079 - accuracy: 0.9881 - iou_metric: 0.3006
# Epoch 11: val_iou_metric improved from 0.40556 to 0.40914, saving model to unet-3d.hdf5
# 230/230 [==============================] - 16s 69ms/step - loss: 0.3079 - accuracy: 0.9881 - iou_metric: 0.3006 - val_loss: 0.2355 - val_accuracy: 0.9884 - val_iou_metric: 0.4091 - lr: 1.0000e-04
# Epoch 12/60
# 230/230 [==============================] - ETA: 0s - loss: 0.3159 - accuracy: 0.9838 - iou_metric: 0.2828
# Epoch 12: val_iou_metric did not improve from 0.40914
# 230/230 [==============================] - 17s 73ms/step - loss: 0.3159 - accuracy: 0.9838 - iou_metric: 0.2828 - val_loss: 0.2393 - val_accuracy: 0.9888 - val_iou_metric: 0.4047 - lr: 1.0000e-04
# Epoch 13/60
# 230/230 [==============================] - ETA: 0s - loss: 0.3044 - accuracy: 0.9869 - iou_metric: 0.2988
# Epoch 13: val_iou_metric did not improve from 0.40914
# 230/230 [==============================] - 17s 74ms/step - loss: 0.3044 - accuracy: 0.9869 - iou_metric: 0.2988 - val_loss: 0.2409 - val_accuracy: 0.9889 - val_iou_metric: 0.4043 - lr: 1.0000e-04
# Epoch 14/60
# 230/230 [==============================] - ETA: 0s - loss: 0.3028 - accuracy: 0.9877 - iou_metric: 0.3052
# Epoch 14: val_iou_metric did not improve from 0.40914
# 230/230 [==============================] - 16s 71ms/step - loss: 0.3028 - accuracy: 0.9877 - iou_metric: 0.3052 - val_loss: 0.2513 - val_accuracy: 0.9889 - val_iou_metric: 0.3849 - lr: 1.0000e-04
# Epoch 15/60
# 230/230 [==============================] - ETA: 0s - loss: 0.3042 - accuracy: 0.9862 - iou_metric: 0.2986
# Epoch 15: val_iou_metric improved from 0.40914 to 0.42093, saving model to unet-3d.hdf5
# 230/230 [==============================] - 15s 67ms/step - loss: 0.3042 - accuracy: 0.9862 - iou_metric: 0.2986 - val_loss: 0.2261 - val_accuracy: 0.9890 - val_iou_metric: 0.4209 - lr: 1.0000e-04
# Epoch 16/60
# 230/230 [==============================] - ETA: 0s - loss: 0.3079 - accuracy: 0.9887 - iou_metric: 0.2951
# Epoch 16: val_iou_metric did not improve from 0.42093
# 230/230 [==============================] - 15s 66ms/step - loss: 0.3079 - accuracy: 0.9887 - iou_metric: 0.2951 - val_loss: 0.2380 - val_accuracy: 0.9894 - val_iou_metric: 0.4011 - lr: 1.0000e-04
# Epoch 17/60
# 230/230 [==============================] - ETA: 0s - loss: 0.3029 - accuracy: 0.9879 - iou_metric: 0.3052
# Epoch 17: val_iou_metric did not improve from 0.42093
# 230/230 [==============================] - 15s 65ms/step - loss: 0.3029 - accuracy: 0.9879 - iou_metric: 0.3052 - val_loss: 0.2352 - val_accuracy: 0.9866 - val_iou_metric: 0.4031 - lr: 1.0000e-04
# Epoch 18/60
# 230/230 [==============================] - ETA: 0s - loss: 0.3010 - accuracy: 0.9876 - iou_metric: 0.3033
# Epoch 18: val_iou_metric did not improve from 0.42093
# 230/230 [==============================] - 16s 69ms/step - loss: 0.3010 - accuracy: 0.9876 - iou_metric: 0.3033 - val_loss: 0.2281 - val_accuracy: 0.9875 - val_iou_metric: 0.4185 - lr: 1.0000e-04
# Epoch 19/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2978 - accuracy: 0.9886 - iou_metric: 0.3104
# Epoch 19: val_iou_metric did not improve from 0.42093
# 230/230 [==============================] - 17s 72ms/step - loss: 0.2978 - accuracy: 0.9886 - iou_metric: 0.3104 - val_loss: 0.2470 - val_accuracy: 0.9911 - val_iou_metric: 0.3974 - lr: 1.0000e-04
# Epoch 20/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2981 - accuracy: 0.9883 - iou_metric: 0.3090
# Epoch 20: val_iou_metric did not improve from 0.42093
# 230/230 [==============================] - 17s 75ms/step - loss: 0.2981 - accuracy: 0.9883 - iou_metric: 0.3090 - val_loss: 0.2452 - val_accuracy: 0.9914 - val_iou_metric: 0.3986 - lr: 1.0000e-04
# Epoch 21/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2902 - accuracy: 0.9884 - iou_metric: 0.3209
# Epoch 21: val_iou_metric did not improve from 0.42093
# 230/230 [==============================] - 15s 66ms/step - loss: 0.2902 - accuracy: 0.9884 - iou_metric: 0.3209 - val_loss: 0.2378 - val_accuracy: 0.9917 - val_iou_metric: 0.4113 - lr: 1.0000e-04
# Epoch 22/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2925 - accuracy: 0.9880 - iou_metric: 0.3196
# Epoch 22: val_iou_metric improved from 0.42093 to 0.43929, saving model to unet-3d.hdf5
# 230/230 [==============================] - 16s 69ms/step - loss: 0.2925 - accuracy: 0.9880 - iou_metric: 0.3196 - val_loss: 0.2188 - val_accuracy: 0.9900 - val_iou_metric: 0.4393 - lr: 1.0000e-04
# Epoch 23/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2881 - accuracy: 0.9890 - iou_metric: 0.3256
# Epoch 23: val_iou_metric improved from 0.43929 to 0.44077, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 80ms/step - loss: 0.2881 - accuracy: 0.9890 - iou_metric: 0.3256 - val_loss: 0.2163 - val_accuracy: 0.9902 - val_iou_metric: 0.4408 - lr: 1.0000e-04
# Epoch 24/60
# 230/230 [==============================] - ETA: 0s - loss: 0.3027 - accuracy: 0.9864 - iou_metric: 0.3008
# Epoch 24: val_iou_metric improved from 0.44077 to 0.44099, saving model to unet-3d.hdf5
# 230/230 [==============================] - 19s 81ms/step - loss: 0.3027 - accuracy: 0.9864 - iou_metric: 0.3008 - val_loss: 0.2173 - val_accuracy: 0.9904 - val_iou_metric: 0.4410 - lr: 1.0000e-04
# Epoch 25/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2882 - accuracy: 0.9890 - iou_metric: 0.3215
# Epoch 25: val_iou_metric did not improve from 0.44099
# 230/230 [==============================] - 16s 72ms/step - loss: 0.2882 - accuracy: 0.9890 - iou_metric: 0.3215 - val_loss: 0.2158 - val_accuracy: 0.9889 - val_iou_metric: 0.4387 - lr: 1.0000e-04
# Epoch 26/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2832 - accuracy: 0.9894 - iou_metric: 0.3310
# Epoch 26: val_iou_metric did not improve from 0.44099
# 230/230 [==============================] - 18s 76ms/step - loss: 0.2832 - accuracy: 0.9894 - iou_metric: 0.3310 - val_loss: 0.2180 - val_accuracy: 0.9889 - val_iou_metric: 0.4388 - lr: 1.0000e-04
# Epoch 27/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2896 - accuracy: 0.9897 - iou_metric: 0.3251
# Epoch 27: val_iou_metric did not improve from 0.44099
# 230/230 [==============================] - 18s 79ms/step - loss: 0.2896 - accuracy: 0.9897 - iou_metric: 0.3251 - val_loss: 0.2237 - val_accuracy: 0.9898 - val_iou_metric: 0.4285 - lr: 1.0000e-04
# Epoch 28/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2884 - accuracy: 0.9902 - iou_metric: 0.3261
# Epoch 28: val_iou_metric did not improve from 0.44099
# 230/230 [==============================] - 18s 78ms/step - loss: 0.2884 - accuracy: 0.9902 - iou_metric: 0.3261 - val_loss: 0.3324 - val_accuracy: 0.9919 - val_iou_metric: 0.2835 - lr: 1.0000e-04
# Epoch 29/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2903 - accuracy: 0.9900 - iou_metric: 0.3234
# Epoch 29: val_iou_metric did not improve from 0.44099
# 230/230 [==============================] - 18s 78ms/step - loss: 0.2903 - accuracy: 0.9900 - iou_metric: 0.3234 - val_loss: 0.2231 - val_accuracy: 0.9902 - val_iou_metric: 0.4291 - lr: 1.0000e-04
# Epoch 30/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2827 - accuracy: 0.9884 - iou_metric: 0.3336
# Epoch 30: val_iou_metric did not improve from 0.44099
# 230/230 [==============================] - 18s 79ms/step - loss: 0.2827 - accuracy: 0.9884 - iou_metric: 0.3336 - val_loss: 0.2253 - val_accuracy: 0.9891 - val_iou_metric: 0.4298 - lr: 1.0000e-04
# Epoch 31/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2866 - accuracy: 0.9876 - iou_metric: 0.3279
# Epoch 31: val_iou_metric did not improve from 0.44099
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 230/230 [==============================] - 17s 73ms/step - loss: 0.2866 - accuracy: 0.9876 - iou_metric: 0.3279 - val_loss: 0.2587 - val_accuracy: 0.9920 - val_iou_metric: 0.3765 - lr: 1.0000e-04
# Epoch 32/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2795 - accuracy: 0.9901 - iou_metric: 0.3384
# Epoch 32: val_iou_metric improved from 0.44099 to 0.44370, saving model to unet-3d.hdf5
# 230/230 [==============================] - 17s 72ms/step - loss: 0.2795 - accuracy: 0.9901 - iou_metric: 0.3384 - val_loss: 0.2152 - val_accuracy: 0.9901 - val_iou_metric: 0.4437 - lr: 5.0000e-05
# Epoch 33/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2691 - accuracy: 0.9902 - iou_metric: 0.3554
# Epoch 33: val_iou_metric improved from 0.44370 to 0.45043, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 81ms/step - loss: 0.2691 - accuracy: 0.9902 - iou_metric: 0.3554 - val_loss: 0.2092 - val_accuracy: 0.9901 - val_iou_metric: 0.4504 - lr: 5.0000e-05
# Epoch 34/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2641 - accuracy: 0.9906 - iou_metric: 0.3632
# Epoch 34: val_iou_metric did not improve from 0.45043
# 230/230 [==============================] - 15s 67ms/step - loss: 0.2641 - accuracy: 0.9906 - iou_metric: 0.3632 - val_loss: 0.2255 - val_accuracy: 0.9889 - val_iou_metric: 0.4177 - lr: 5.0000e-05
# Epoch 35/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2657 - accuracy: 0.9907 - iou_metric: 0.3606
# Epoch 35: val_iou_metric improved from 0.45043 to 0.45445, saving model to unet-3d.hdf5
# 230/230 [==============================] - 16s 70ms/step - loss: 0.2657 - accuracy: 0.9907 - iou_metric: 0.3606 - val_loss: 0.2098 - val_accuracy: 0.9922 - val_iou_metric: 0.4544 - lr: 5.0000e-05
# Epoch 36/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2668 - accuracy: 0.9908 - iou_metric: 0.3596
# Epoch 36: val_iou_metric did not improve from 0.45445
# 230/230 [==============================] - 17s 75ms/step - loss: 0.2668 - accuracy: 0.9908 - iou_metric: 0.3596 - val_loss: 0.2094 - val_accuracy: 0.9908 - val_iou_metric: 0.4524 - lr: 5.0000e-05
# Epoch 37/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2669 - accuracy: 0.9907 - iou_metric: 0.3590
# Epoch 37: val_iou_metric improved from 0.45445 to 0.46567, saving model to unet-3d.hdf5
# 230/230 [==============================] - 19s 81ms/step - loss: 0.2669 - accuracy: 0.9907 - iou_metric: 0.3590 - val_loss: 0.2035 - val_accuracy: 0.9910 - val_iou_metric: 0.4657 - lr: 5.0000e-05
# Epoch 38/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2625 - accuracy: 0.9907 - iou_metric: 0.3651
# Epoch 38: val_iou_metric did not improve from 0.46567
# 230/230 [==============================] - 18s 77ms/step - loss: 0.2625 - accuracy: 0.9907 - iou_metric: 0.3651 - val_loss: 0.2083 - val_accuracy: 0.9914 - val_iou_metric: 0.4558 - lr: 5.0000e-05
# Epoch 39/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2652 - accuracy: 0.9909 - iou_metric: 0.3614
# Epoch 39: val_iou_metric improved from 0.46567 to 0.46753, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 78ms/step - loss: 0.2652 - accuracy: 0.9909 - iou_metric: 0.3614 - val_loss: 0.2026 - val_accuracy: 0.9919 - val_iou_metric: 0.4675 - lr: 5.0000e-05
# Epoch 40/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2632 - accuracy: 0.9909 - iou_metric: 0.3666
# Epoch 40: val_iou_metric did not improve from 0.46753
# 230/230 [==============================] - 16s 72ms/step - loss: 0.2632 - accuracy: 0.9909 - iou_metric: 0.3666 - val_loss: 0.2099 - val_accuracy: 0.9917 - val_iou_metric: 0.4544 - lr: 5.0000e-05
# Epoch 41/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2618 - accuracy: 0.9911 - iou_metric: 0.3690
# Epoch 41: val_iou_metric improved from 0.46753 to 0.47216, saving model to unet-3d.hdf5
# 230/230 [==============================] - 15s 65ms/step - loss: 0.2618 - accuracy: 0.9911 - iou_metric: 0.3690 - val_loss: 0.1998 - val_accuracy: 0.9919 - val_iou_metric: 0.4722 - lr: 5.0000e-05
# Epoch 42/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2623 - accuracy: 0.9907 - iou_metric: 0.3651
# Epoch 42: val_iou_metric did not improve from 0.47216
# 230/230 [==============================] - 15s 65ms/step - loss: 0.2623 - accuracy: 0.9907 - iou_metric: 0.3651 - val_loss: 0.2105 - val_accuracy: 0.9903 - val_iou_metric: 0.4471 - lr: 5.0000e-05
# Epoch 43/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2578 - accuracy: 0.9916 - iou_metric: 0.3755
# Epoch 43: val_iou_metric improved from 0.47216 to 0.47506, saving model to unet-3d.hdf5
# 230/230 [==============================] - 16s 71ms/step - loss: 0.2578 - accuracy: 0.9916 - iou_metric: 0.3755 - val_loss: 0.1995 - val_accuracy: 0.9924 - val_iou_metric: 0.4751 - lr: 5.0000e-05
# Epoch 44/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2593 - accuracy: 0.9908 - iou_metric: 0.3698
# Epoch 44: val_iou_metric did not improve from 0.47506
# 230/230 [==============================] - 16s 71ms/step - loss: 0.2593 - accuracy: 0.9908 - iou_metric: 0.3698 - val_loss: 0.2007 - val_accuracy: 0.9916 - val_iou_metric: 0.4727 - lr: 5.0000e-05
# Epoch 45/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2601 - accuracy: 0.9909 - iou_metric: 0.3693
# Epoch 45: val_iou_metric did not improve from 0.47506
# 230/230 [==============================] - 15s 64ms/step - loss: 0.2601 - accuracy: 0.9909 - iou_metric: 0.3693 - val_loss: 0.2018 - val_accuracy: 0.9906 - val_iou_metric: 0.4674 - lr: 5.0000e-05
# Epoch 46/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2603 - accuracy: 0.9910 - iou_metric: 0.3702
# Epoch 46: val_iou_metric did not improve from 0.47506
# 230/230 [==============================] - 14s 63ms/step - loss: 0.2603 - accuracy: 0.9910 - iou_metric: 0.3702 - val_loss: 0.2014 - val_accuracy: 0.9907 - val_iou_metric: 0.4670 - lr: 5.0000e-05
# Epoch 47/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2571 - accuracy: 0.9913 - iou_metric: 0.3756
# Epoch 47: val_iou_metric did not improve from 0.47506
# 230/230 [==============================] - 16s 69ms/step - loss: 0.2571 - accuracy: 0.9913 - iou_metric: 0.3756 - val_loss: 0.2015 - val_accuracy: 0.9910 - val_iou_metric: 0.4676 - lr: 5.0000e-05
# Epoch 48/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2561 - accuracy: 0.9908 - iou_metric: 0.3787
# Epoch 48: val_iou_metric improved from 0.47506 to 0.47718, saving model to unet-3d.hdf5
# 230/230 [==============================] - 16s 70ms/step - loss: 0.2561 - accuracy: 0.9908 - iou_metric: 0.3787 - val_loss: 0.1977 - val_accuracy: 0.9923 - val_iou_metric: 0.4772 - lr: 5.0000e-05
# Epoch 49/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2568 - accuracy: 0.9913 - iou_metric: 0.3760
# Epoch 49: val_iou_metric did not improve from 0.47718
# 230/230 [==============================] - 16s 71ms/step - loss: 0.2568 - accuracy: 0.9913 - iou_metric: 0.3760 - val_loss: 0.1998 - val_accuracy: 0.9911 - val_iou_metric: 0.4712 - lr: 5.0000e-05
# Epoch 50/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2562 - accuracy: 0.9913 - iou_metric: 0.3784
# Epoch 50: val_iou_metric improved from 0.47718 to 0.48233, saving model to unet-3d.hdf5
# 230/230 [==============================] - 19s 82ms/step - loss: 0.2562 - accuracy: 0.9913 - iou_metric: 0.3784 - val_loss: 0.1961 - val_accuracy: 0.9923 - val_iou_metric: 0.4823 - lr: 5.0000e-05
# Epoch 51/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2543 - accuracy: 0.9910 - iou_metric: 0.3801
# Epoch 51: val_iou_metric improved from 0.48233 to 0.48253, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 79ms/step - loss: 0.2543 - accuracy: 0.9910 - iou_metric: 0.3801 - val_loss: 0.1943 - val_accuracy: 0.9921 - val_iou_metric: 0.4825 - lr: 5.0000e-05
# Epoch 52/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2501 - accuracy: 0.9917 - iou_metric: 0.3891
# Epoch 52: val_iou_metric did not improve from 0.48253
# 230/230 [==============================] - 17s 75ms/step - loss: 0.2501 - accuracy: 0.9917 - iou_metric: 0.3891 - val_loss: 0.1982 - val_accuracy: 0.9915 - val_iou_metric: 0.4728 - lr: 5.0000e-05
# Epoch 53/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2518 - accuracy: 0.9915 - iou_metric: 0.3848
# Epoch 53: val_iou_metric improved from 0.48253 to 0.48277, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 78ms/step - loss: 0.2518 - accuracy: 0.9915 - iou_metric: 0.3848 - val_loss: 0.1939 - val_accuracy: 0.9914 - val_iou_metric: 0.4828 - lr: 5.0000e-05
# Epoch 54/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2506 - accuracy: 0.9915 - iou_metric: 0.3879
# Epoch 54: val_iou_metric did not improve from 0.48277
# 230/230 [==============================] - 18s 79ms/step - loss: 0.2506 - accuracy: 0.9915 - iou_metric: 0.3879 - val_loss: 0.1977 - val_accuracy: 0.9909 - val_iou_metric: 0.4742 - lr: 5.0000e-05
# Epoch 55/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2512 - accuracy: 0.9914 - iou_metric: 0.3866
# Epoch 55: val_iou_metric improved from 0.48277 to 0.48361, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 79ms/step - loss: 0.2512 - accuracy: 0.9914 - iou_metric: 0.3866 - val_loss: 0.1931 - val_accuracy: 0.9919 - val_iou_metric: 0.4836 - lr: 5.0000e-05
# Epoch 56/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2478 - accuracy: 0.9915 - iou_metric: 0.3913
# Epoch 56: val_iou_metric improved from 0.48361 to 0.50021, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 80ms/step - loss: 0.2478 - accuracy: 0.9915 - iou_metric: 0.3913 - val_loss: 0.1862 - val_accuracy: 0.9924 - val_iou_metric: 0.5002 - lr: 5.0000e-05
# Epoch 57/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2508 - accuracy: 0.9916 - iou_metric: 0.3857
# Epoch 57: val_iou_metric did not improve from 0.50021
# 230/230 [==============================] - 19s 81ms/step - loss: 0.2508 - accuracy: 0.9916 - iou_metric: 0.3857 - val_loss: 0.2033 - val_accuracy: 0.9929 - val_iou_metric: 0.4721 - lr: 5.0000e-05
# Epoch 58/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2488 - accuracy: 0.9909 - iou_metric: 0.3894
# Epoch 58: val_iou_metric did not improve from 0.50021
# 230/230 [==============================] - 18s 78ms/step - loss: 0.2488 - accuracy: 0.9909 - iou_metric: 0.3894 - val_loss: 0.2025 - val_accuracy: 0.9925 - val_iou_metric: 0.4721 - lr: 5.0000e-05
# Epoch 59/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2455 - accuracy: 0.9923 - iou_metric: 0.3975
# Epoch 59: val_iou_metric did not improve from 0.50021
# 230/230 [==============================] - 18s 76ms/step - loss: 0.2455 - accuracy: 0.9923 - iou_metric: 0.3975 - val_loss: 0.1917 - val_accuracy: 0.9922 - val_iou_metric: 0.4876 - lr: 5.0000e-05
# Epoch 60/60
# 230/230 [==============================] - ETA: 0s - loss: 0.2444 - accuracy: 0.9915 - iou_metric: 0.3964
# Epoch 60: val_iou_metric did not improve from 0.50021
# 230/230 [==============================] - 18s 77ms/step - loss: 0.2444 - accuracy: 0.9915 - iou_metric: 0.3964 - val_loss: 0.1926 - val_accuracy: 0.9915 - val_iou_metric: 0.4861 - lr: 5.0000e-05

# %%
# Save model history
np.save('unet-attention-3d-history.npy',model_attention_unet.history.history)

# %% [markdown]
# ## ResNet50-SegNet

# %%
R = ResNet50SegNet()
save_model_resnet = ModelCheckpoint('resnet50segnet-3d.hdf5', monitor='val_iou_metric',verbose=1, save_best_only=True, save_weights_only=True, mode='max')
train = trainGenerator(1, t_images, t_masks, data_gen_args, save_to_dir=None)
R.fit(train, steps_per_epoch = 230, epochs=50, validation_data = validation_Nepal_landslide_dataset, callbacks=[save_model_resnet, reduce_lr])
# Out:
# Epoch 1/50
# 230/230 [==============================] - ETA: 0s - loss: 0.4615 - accuracy: 0.9325 - iou_metric: 0.0689
# Epoch 1: val_iou_metric improved from -inf to 0.17163, saving model to resnet50segnet-3d.hdf5
# 230/230 [==============================] - 43s 145ms/step - loss: 0.4615 - accuracy: 0.9325 - iou_metric: 0.0689 - val_loss: 0.4077 - val_accuracy: 0.9869 - val_iou_metric: 0.1716 - lr: 1.0000e-04
# Epoch 2/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3915 - accuracy: 0.9558 - iou_metric: 0.1821
# Epoch 2: val_iou_metric improved from 0.17163 to 0.28758, saving model to resnet50segnet-3d.hdf5
# 230/230 [==============================] - 32s 138ms/step - loss: 0.3915 - accuracy: 0.9558 - iou_metric: 0.1821 - val_loss: 0.3005 - val_accuracy: 0.9803 - val_iou_metric: 0.2876 - lr: 1.0000e-04
# Epoch 3/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3620 - accuracy: 0.9720 - iou_metric: 0.2223
# Epoch 3: val_iou_metric improved from 0.28758 to 0.35035, saving model to resnet50segnet-3d.hdf5
# 230/230 [==============================] - 31s 136ms/step - loss: 0.3620 - accuracy: 0.9720 - iou_metric: 0.2223 - val_loss: 0.2678 - val_accuracy: 0.9824 - val_iou_metric: 0.3504 - lr: 1.0000e-04
# Epoch 4/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3412 - accuracy: 0.9787 - iou_metric: 0.2509
# Epoch 4: val_iou_metric improved from 0.35035 to 0.35984, saving model to resnet50segnet-3d.hdf5
# 230/230 [==============================] - 31s 137ms/step - loss: 0.3412 - accuracy: 0.9787 - iou_metric: 0.2509 - val_loss: 0.2614 - val_accuracy: 0.9871 - val_iou_metric: 0.3598 - lr: 1.0000e-04
# Epoch 5/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3405 - accuracy: 0.9766 - iou_metric: 0.2512
# Epoch 5: val_iou_metric did not improve from 0.35984
# 230/230 [==============================] - 31s 133ms/step - loss: 0.3405 - accuracy: 0.9766 - iou_metric: 0.2512 - val_loss: 0.2743 - val_accuracy: 0.9781 - val_iou_metric: 0.3294 - lr: 1.0000e-04
# Epoch 6/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3407 - accuracy: 0.9747 - iou_metric: 0.2495
# Epoch 6: val_iou_metric did not improve from 0.35984
# 230/230 [==============================] - 31s 134ms/step - loss: 0.3407 - accuracy: 0.9747 - iou_metric: 0.2495 - val_loss: 0.2581 - val_accuracy: 0.9816 - val_iou_metric: 0.3576 - lr: 1.0000e-04
# Epoch 7/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3320 - accuracy: 0.9796 - iou_metric: 0.2591
# Epoch 7: val_iou_metric improved from 0.35984 to 0.38438, saving model to resnet50segnet-3d.hdf5
# 230/230 [==============================] - 31s 136ms/step - loss: 0.3320 - accuracy: 0.9796 - iou_metric: 0.2591 - val_loss: 0.2508 - val_accuracy: 0.9902 - val_iou_metric: 0.3844 - lr: 1.0000e-04
# Epoch 8/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3491 - accuracy: 0.9748 - iou_metric: 0.2318
# Epoch 8: val_iou_metric did not improve from 0.38438
# 230/230 [==============================] - 31s 135ms/step - loss: 0.3491 - accuracy: 0.9748 - iou_metric: 0.2318 - val_loss: 0.2471 - val_accuracy: 0.9887 - val_iou_metric: 0.3838 - lr: 1.0000e-04
# Epoch 9/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3341 - accuracy: 0.9841 - iou_metric: 0.2588
# Epoch 9: val_iou_metric did not improve from 0.38438
# 230/230 [==============================] - 31s 134ms/step - loss: 0.3341 - accuracy: 0.9841 - iou_metric: 0.2588 - val_loss: 0.4567 - val_accuracy: 0.9873 - val_iou_metric: 0.0827 - lr: 1.0000e-04
# Epoch 10/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3414 - accuracy: 0.9805 - iou_metric: 0.2587
# Epoch 10: val_iou_metric improved from 0.38438 to 0.38899, saving model to resnet50segnet-3d.hdf5
# 230/230 [==============================] - 31s 137ms/step - loss: 0.3414 - accuracy: 0.9805 - iou_metric: 0.2587 - val_loss: 0.2469 - val_accuracy: 0.9895 - val_iou_metric: 0.3890 - lr: 1.0000e-04
# Epoch 11/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3199 - accuracy: 0.9828 - iou_metric: 0.2800
# Epoch 11: val_iou_metric did not improve from 0.38899
# 230/230 [==============================] - 31s 134ms/step - loss: 0.3199 - accuracy: 0.9828 - iou_metric: 0.2800 - val_loss: 0.2457 - val_accuracy: 0.9839 - val_iou_metric: 0.3859 - lr: 1.0000e-04
# Epoch 12/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3244 - accuracy: 0.9808 - iou_metric: 0.2726
# Epoch 12: val_iou_metric did not improve from 0.38899
# 230/230 [==============================] - 31s 134ms/step - loss: 0.3244 - accuracy: 0.9808 - iou_metric: 0.2726 - val_loss: 0.2557 - val_accuracy: 0.9821 - val_iou_metric: 0.3654 - lr: 1.0000e-04
# Epoch 13/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3087 - accuracy: 0.9858 - iou_metric: 0.2953
# Epoch 13: val_iou_metric did not improve from 0.38899
# 230/230 [==============================] - 31s 133ms/step - loss: 0.3087 - accuracy: 0.9858 - iou_metric: 0.2953 - val_loss: 0.5479 - val_accuracy: 0.8167 - val_iou_metric: 0.0361 - lr: 1.0000e-04
# Epoch 14/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3450 - accuracy: 0.9789 - iou_metric: 0.2378
# Epoch 14: val_iou_metric did not improve from 0.38899
# 230/230 [==============================] - 31s 134ms/step - loss: 0.3450 - accuracy: 0.9789 - iou_metric: 0.2378 - val_loss: 0.2777 - val_accuracy: 0.9813 - val_iou_metric: 0.3257 - lr: 1.0000e-04
# Epoch 15/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3385 - accuracy: 0.9779 - iou_metric: 0.2420
# Epoch 15: val_iou_metric did not improve from 0.38899
# 230/230 [==============================] - 30s 131ms/step - loss: 0.3385 - accuracy: 0.9779 - iou_metric: 0.2420 - val_loss: 0.3246 - val_accuracy: 0.9674 - val_iou_metric: 0.2518 - lr: 1.0000e-04
# Epoch 16/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3311 - accuracy: 0.9826 - iou_metric: 0.2574
# Epoch 16: val_iou_metric did not improve from 0.38899
# 230/230 [==============================] - 31s 133ms/step - loss: 0.3311 - accuracy: 0.9826 - iou_metric: 0.2574 - val_loss: 0.2512 - val_accuracy: 0.9872 - val_iou_metric: 0.3744 - lr: 1.0000e-04
# Epoch 17/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3414 - accuracy: 0.9719 - iou_metric: 0.2425
# Epoch 17: val_iou_metric did not improve from 0.38899
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 230/230 [==============================] - 31s 135ms/step - loss: 0.3414 - accuracy: 0.9719 - iou_metric: 0.2425 - val_loss: 0.2672 - val_accuracy: 0.9800 - val_iou_metric: 0.3453 - lr: 1.0000e-04
# Epoch 18/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3189 - accuracy: 0.9794 - iou_metric: 0.2722
# Epoch 18: val_iou_metric did not improve from 0.38899
# 230/230 [==============================] - 31s 134ms/step - loss: 0.3189 - accuracy: 0.9794 - iou_metric: 0.2722 - val_loss: 0.2524 - val_accuracy: 0.9851 - val_iou_metric: 0.3689 - lr: 5.0000e-05
# Epoch 19/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3249 - accuracy: 0.9765 - iou_metric: 0.2634
# Epoch 19: val_iou_metric did not improve from 0.38899
# 230/230 [==============================] - 31s 133ms/step - loss: 0.3249 - accuracy: 0.9765 - iou_metric: 0.2634 - val_loss: 0.2573 - val_accuracy: 0.9890 - val_iou_metric: 0.3672 - lr: 5.0000e-05
# Epoch 20/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3175 - accuracy: 0.9840 - iou_metric: 0.2731
# Epoch 20: val_iou_metric did not improve from 0.38899
# 230/230 [==============================] - 31s 133ms/step - loss: 0.3175 - accuracy: 0.9840 - iou_metric: 0.2731 - val_loss: 0.2499 - val_accuracy: 0.9853 - val_iou_metric: 0.3746 - lr: 5.0000e-05
# Epoch 21/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3136 - accuracy: 0.9855 - iou_metric: 0.2793
# Epoch 21: val_iou_metric did not improve from 0.38899
# 230/230 [==============================] - 31s 134ms/step - loss: 0.3136 - accuracy: 0.9855 - iou_metric: 0.2793 - val_loss: 0.2451 - val_accuracy: 0.9888 - val_iou_metric: 0.3824 - lr: 5.0000e-05
# Epoch 22/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3155 - accuracy: 0.9850 - iou_metric: 0.2796
# Epoch 22: val_iou_metric did not improve from 0.38899
# 230/230 [==============================] - 31s 134ms/step - loss: 0.3155 - accuracy: 0.9850 - iou_metric: 0.2796 - val_loss: 0.2481 - val_accuracy: 0.9874 - val_iou_metric: 0.3761 - lr: 5.0000e-05
# Epoch 23/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3063 - accuracy: 0.9847 - iou_metric: 0.2903
# Epoch 23: val_iou_metric did not improve from 0.38899
# 230/230 [==============================] - 31s 134ms/step - loss: 0.3063 - accuracy: 0.9847 - iou_metric: 0.2903 - val_loss: 0.2431 - val_accuracy: 0.9871 - val_iou_metric: 0.3846 - lr: 5.0000e-05
# Epoch 24/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3082 - accuracy: 0.9845 - iou_metric: 0.2890
# Epoch 24: val_iou_metric improved from 0.38899 to 0.39565, saving model to resnet50segnet-3d.hdf5
# 230/230 [==============================] - 31s 136ms/step - loss: 0.3082 - accuracy: 0.9845 - iou_metric: 0.2890 - val_loss: 0.2375 - val_accuracy: 0.9886 - val_iou_metric: 0.3957 - lr: 5.0000e-05
# Epoch 25/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3049 - accuracy: 0.9848 - iou_metric: 0.2938
# Epoch 25: val_iou_metric improved from 0.39565 to 0.39902, saving model to resnet50segnet-3d.hdf5
# 230/230 [==============================] - 31s 136ms/step - loss: 0.3049 - accuracy: 0.9848 - iou_metric: 0.2938 - val_loss: 0.2351 - val_accuracy: 0.9878 - val_iou_metric: 0.3990 - lr: 5.0000e-05
# Epoch 26/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3060 - accuracy: 0.9856 - iou_metric: 0.2941
# Epoch 26: val_iou_metric did not improve from 0.39902
# 230/230 [==============================] - 30s 133ms/step - loss: 0.3060 - accuracy: 0.9856 - iou_metric: 0.2941 - val_loss: 0.2477 - val_accuracy: 0.9857 - val_iou_metric: 0.3788 - lr: 5.0000e-05
# Epoch 27/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3033 - accuracy: 0.9856 - iou_metric: 0.2987
# Epoch 27: val_iou_metric did not improve from 0.39902
# 230/230 [==============================] - 31s 135ms/step - loss: 0.3033 - accuracy: 0.9856 - iou_metric: 0.2987 - val_loss: 0.2364 - val_accuracy: 0.9874 - val_iou_metric: 0.3969 - lr: 5.0000e-05
# Epoch 28/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3028 - accuracy: 0.9862 - iou_metric: 0.3000
# Epoch 28: val_iou_metric did not improve from 0.39902
# 230/230 [==============================] - 31s 134ms/step - loss: 0.3028 - accuracy: 0.9862 - iou_metric: 0.3000 - val_loss: 0.2530 - val_accuracy: 0.9905 - val_iou_metric: 0.3808 - lr: 5.0000e-05
# Epoch 29/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3038 - accuracy: 0.9853 - iou_metric: 0.2996
# Epoch 29: val_iou_metric improved from 0.39902 to 0.39917, saving model to resnet50segnet-3d.hdf5
# 230/230 [==============================] - 31s 135ms/step - loss: 0.3038 - accuracy: 0.9853 - iou_metric: 0.2996 - val_loss: 0.2373 - val_accuracy: 0.9882 - val_iou_metric: 0.3992 - lr: 5.0000e-05
# Epoch 30/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3053 - accuracy: 0.9840 - iou_metric: 0.2944
# Epoch 30: val_iou_metric improved from 0.39917 to 0.40346, saving model to resnet50segnet-3d.hdf5
# 230/230 [==============================] - 31s 136ms/step - loss: 0.3053 - accuracy: 0.9840 - iou_metric: 0.2944 - val_loss: 0.2330 - val_accuracy: 0.9871 - val_iou_metric: 0.4035 - lr: 5.0000e-05
# Epoch 31/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2978 - accuracy: 0.9861 - iou_metric: 0.3055
# Epoch 31: val_iou_metric did not improve from 0.40346
# 230/230 [==============================] - 31s 133ms/step - loss: 0.2978 - accuracy: 0.9861 - iou_metric: 0.3055 - val_loss: 0.2381 - val_accuracy: 0.9887 - val_iou_metric: 0.3979 - lr: 5.0000e-05
# Epoch 32/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2980 - accuracy: 0.9871 - iou_metric: 0.3057
# Epoch 32: val_iou_metric did not improve from 0.40346
# 230/230 [==============================] - 31s 135ms/step - loss: 0.2980 - accuracy: 0.9871 - iou_metric: 0.3057 - val_loss: 0.2488 - val_accuracy: 0.9833 - val_iou_metric: 0.3758 - lr: 5.0000e-05
# Epoch 33/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2947 - accuracy: 0.9865 - iou_metric: 0.3122
# Epoch 33: val_iou_metric improved from 0.40346 to 0.40474, saving model to resnet50segnet-3d.hdf5
# 230/230 [==============================] - 32s 137ms/step - loss: 0.2947 - accuracy: 0.9865 - iou_metric: 0.3122 - val_loss: 0.2314 - val_accuracy: 0.9889 - val_iou_metric: 0.4047 - lr: 5.0000e-05
# Epoch 34/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2903 - accuracy: 0.9873 - iou_metric: 0.3178
# Epoch 34: val_iou_metric improved from 0.40474 to 0.40822, saving model to resnet50segnet-3d.hdf5
# 230/230 [==============================] - 31s 136ms/step - loss: 0.2903 - accuracy: 0.9873 - iou_metric: 0.3178 - val_loss: 0.2309 - val_accuracy: 0.9867 - val_iou_metric: 0.4082 - lr: 5.0000e-05
# Epoch 35/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2957 - accuracy: 0.9866 - iou_metric: 0.3115
# Epoch 35: val_iou_metric improved from 0.40822 to 0.42341, saving model to resnet50segnet-3d.hdf5
# 230/230 [==============================] - 32s 137ms/step - loss: 0.2957 - accuracy: 0.9866 - iou_metric: 0.3115 - val_loss: 0.2225 - val_accuracy: 0.9891 - val_iou_metric: 0.4234 - lr: 5.0000e-05
# Epoch 36/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3038 - accuracy: 0.9848 - iou_metric: 0.2967
# Epoch 36: val_iou_metric did not improve from 0.42341
# 230/230 [==============================] - 31s 133ms/step - loss: 0.3038 - accuracy: 0.9848 - iou_metric: 0.2967 - val_loss: 0.2355 - val_accuracy: 0.9873 - val_iou_metric: 0.3990 - lr: 5.0000e-05
# Epoch 37/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2904 - accuracy: 0.9849 - iou_metric: 0.3167
# Epoch 37: val_iou_metric did not improve from 0.42341
# 230/230 [==============================] - 31s 133ms/step - loss: 0.2904 - accuracy: 0.9849 - iou_metric: 0.3167 - val_loss: 0.2346 - val_accuracy: 0.9886 - val_iou_metric: 0.3995 - lr: 5.0000e-05
# Epoch 38/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2968 - accuracy: 0.9851 - iou_metric: 0.3077
# Epoch 38: val_iou_metric did not improve from 0.42341
# 230/230 [==============================] - 31s 133ms/step - loss: 0.2968 - accuracy: 0.9851 - iou_metric: 0.3077 - val_loss: 0.2314 - val_accuracy: 0.9885 - val_iou_metric: 0.4063 - lr: 5.0000e-05
# Epoch 39/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2905 - accuracy: 0.9867 - iou_metric: 0.3164
# Epoch 39: val_iou_metric improved from 0.42341 to 0.43287, saving model to resnet50segnet-3d.hdf5
# 230/230 [==============================] - 31s 137ms/step - loss: 0.2905 - accuracy: 0.9867 - iou_metric: 0.3164 - val_loss: 0.2183 - val_accuracy: 0.9902 - val_iou_metric: 0.4329 - lr: 5.0000e-05
# Epoch 40/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2898 - accuracy: 0.9872 - iou_metric: 0.3177
# Epoch 40: val_iou_metric did not improve from 0.43287
# 230/230 [==============================] - 31s 133ms/step - loss: 0.2898 - accuracy: 0.9872 - iou_metric: 0.3177 - val_loss: 0.2216 - val_accuracy: 0.9907 - val_iou_metric: 0.4283 - lr: 5.0000e-05
# Epoch 41/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2902 - accuracy: 0.9871 - iou_metric: 0.3148
# Epoch 41: val_iou_metric did not improve from 0.43287
# 230/230 [==============================] - 31s 133ms/step - loss: 0.2902 - accuracy: 0.9871 - iou_metric: 0.3148 - val_loss: 0.2227 - val_accuracy: 0.9898 - val_iou_metric: 0.4246 - lr: 5.0000e-05
# Epoch 42/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2875 - accuracy: 0.9864 - iou_metric: 0.3225
# Epoch 42: val_iou_metric did not improve from 0.43287
# 230/230 [==============================] - 31s 133ms/step - loss: 0.2875 - accuracy: 0.9864 - iou_metric: 0.3225 - val_loss: 0.2291 - val_accuracy: 0.9916 - val_iou_metric: 0.4232 - lr: 5.0000e-05
# Epoch 43/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2954 - accuracy: 0.9865 - iou_metric: 0.3103
# Epoch 43: val_iou_metric did not improve from 0.43287
# 230/230 [==============================] - 31s 134ms/step - loss: 0.2954 - accuracy: 0.9865 - iou_metric: 0.3103 - val_loss: 0.2632 - val_accuracy: 0.9920 - val_iou_metric: 0.3626 - lr: 5.0000e-05
# Epoch 44/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2938 - accuracy: 0.9864 - iou_metric: 0.3113
# Epoch 44: val_iou_metric did not improve from 0.43287
# 230/230 [==============================] - 31s 134ms/step - loss: 0.2938 - accuracy: 0.9864 - iou_metric: 0.3113 - val_loss: 0.2242 - val_accuracy: 0.9908 - val_iou_metric: 0.4274 - lr: 5.0000e-05
# Epoch 45/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2856 - accuracy: 0.9881 - iou_metric: 0.3277
# Epoch 45: val_iou_metric improved from 0.43287 to 0.43651, saving model to resnet50segnet-3d.hdf5
# 230/230 [==============================] - 31s 136ms/step - loss: 0.2856 - accuracy: 0.9881 - iou_metric: 0.3277 - val_loss: 0.2185 - val_accuracy: 0.9896 - val_iou_metric: 0.4365 - lr: 5.0000e-05
# Epoch 46/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2899 - accuracy: 0.9874 - iou_metric: 0.3234
# Epoch 46: val_iou_metric did not improve from 0.43651
# 230/230 [==============================] - 31s 133ms/step - loss: 0.2899 - accuracy: 0.9874 - iou_metric: 0.3234 - val_loss: 0.2336 - val_accuracy: 0.9864 - val_iou_metric: 0.4023 - lr: 5.0000e-05
# Epoch 47/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2981 - accuracy: 0.9845 - iou_metric: 0.3085
# Epoch 47: val_iou_metric did not improve from 0.43651
# 230/230 [==============================] - 31s 134ms/step - loss: 0.2981 - accuracy: 0.9845 - iou_metric: 0.3085 - val_loss: 0.2264 - val_accuracy: 0.9888 - val_iou_metric: 0.4188 - lr: 5.0000e-05
# Epoch 48/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2878 - accuracy: 0.9866 - iou_metric: 0.3211
# Epoch 48: val_iou_metric did not improve from 0.43651
# 230/230 [==============================] - 31s 133ms/step - loss: 0.2878 - accuracy: 0.9866 - iou_metric: 0.3211 - val_loss: 0.2233 - val_accuracy: 0.9904 - val_iou_metric: 0.4257 - lr: 5.0000e-05
# Epoch 49/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2830 - accuracy: 0.9871 - iou_metric: 0.3307
# Epoch 49: val_iou_metric did not improve from 0.43651
# 230/230 [==============================] - 31s 133ms/step - loss: 0.2830 - accuracy: 0.9871 - iou_metric: 0.3307 - val_loss: 0.2428 - val_accuracy: 0.9848 - val_iou_metric: 0.3877 - lr: 5.0000e-05
# Epoch 50/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2804 - accuracy: 0.9885 - iou_metric: 0.3363
# Epoch 50: val_iou_metric improved from 0.43651 to 0.44654, saving model to resnet50segnet-3d.hdf5
# 230/230 [==============================] - 31s 136ms/step - loss: 0.2804 - accuracy: 0.9885 - iou_metric: 0.3363 - val_loss: 0.2115 - val_accuracy: 0.9905 - val_iou_metric: 0.4465 - lr: 5.0000e-05

# %%
# Save model history
np.save('resnet50segnet-3d-history.npy',R.history.history)

# %% [markdown]
# ## FCN32-VGG16

# %%
F = fcn_32(lr = 0.0001)
save_model_fcn32 = ModelCheckpoint('fcn32-3d.hdf5', monitor='val_iou_metric',verbose=1, save_best_only=True, mode='max')
train = trainGenerator(1, t_images, t_masks, data_gen_args, save_to_dir=None)
F.fit(train, steps_per_epoch = 230, epochs=50, validation_data = validation_Nepal_landslide_dataset, callbacks=[save_model_fcn32, reduce_lr])
# Out:
# Epoch 1/50
# 230/230 [==============================] - ETA: 0s - loss: 0.5120 - accuracy: 0.9902 - iou_metric: 3.0147e-05
# Epoch 1: val_iou_metric improved from -inf to 0.00000, saving model to fcn32-3d.hdf5
# 230/230 [==============================] - 25s 98ms/step - loss: 0.5120 - accuracy: 0.9902 - iou_metric: 3.0147e-05 - val_loss: 0.5104 - val_accuracy: 0.9896 - val_iou_metric: 7.5182e-10 - lr: 5.0000e-05
# Epoch 2/50
# 230/230 [==============================] - ETA: 0s - loss: 0.5100 - accuracy: 0.9557 - iou_metric: 0.0027
# Epoch 2: val_iou_metric improved from 0.00000 to 0.00208, saving model to fcn32-3d.hdf5
# 230/230 [==============================] - 21s 94ms/step - loss: 0.5100 - accuracy: 0.9557 - iou_metric: 0.0027 - val_loss: 0.5033 - val_accuracy: 0.9722 - val_iou_metric: 0.0021 - lr: 5.0000e-05
# Epoch 3/50
# 230/230 [==============================] - ETA: 0s - loss: 0.5011 - accuracy: 0.9781 - iou_metric: 0.0035
# Epoch 3: val_iou_metric improved from 0.00208 to 0.01258, saving model to fcn32-3d.hdf5
# 230/230 [==============================] - 20s 89ms/step - loss: 0.5011 - accuracy: 0.9781 - iou_metric: 0.0035 - val_loss: 0.4982 - val_accuracy: 0.9318 - val_iou_metric: 0.0126 - lr: 5.0000e-05
# Epoch 4/50
# 230/230 [==============================] - ETA: 0s - loss: 0.4987 - accuracy: 0.9193 - iou_metric: 0.0094
# Epoch 4: val_iou_metric did not improve from 0.01258
# 230/230 [==============================] - 19s 82ms/step - loss: 0.4987 - accuracy: 0.9193 - iou_metric: 0.0094 - val_loss: 0.4972 - val_accuracy: 0.9895 - val_iou_metric: 7.2588e-10 - lr: 5.0000e-05
# Epoch 5/50
# 230/230 [==============================] - ETA: 0s - loss: 0.4999 - accuracy: 0.8824 - iou_metric: 0.0071
# Epoch 5: val_iou_metric did not improve from 0.01258
# 230/230 [==============================] - 19s 81ms/step - loss: 0.4999 - accuracy: 0.8824 - iou_metric: 0.0071 - val_loss: 0.5018 - val_accuracy: 0.9896 - val_iou_metric: 7.4088e-10 - lr: 5.0000e-05
# Epoch 6/50
# 230/230 [==============================] - ETA: 0s - loss: 0.4975 - accuracy: 0.8986 - iou_metric: 0.0122
# Epoch 6: val_iou_metric improved from 0.01258 to 0.02065, saving model to fcn32-3d.hdf5
# 230/230 [==============================] - 22s 95ms/step - loss: 0.4975 - accuracy: 0.8986 - iou_metric: 0.0122 - val_loss: 0.5003 - val_accuracy: 0.6151 - val_iou_metric: 0.0206 - lr: 5.0000e-05
# Epoch 7/50
# 230/230 [==============================] - ETA: 0s - loss: 0.4972 - accuracy: 0.9014 - iou_metric: 0.0156
# Epoch 7: val_iou_metric improved from 0.02065 to 0.04724, saving model to fcn32-3d.hdf5
# 230/230 [==============================] - 22s 94ms/step - loss: 0.4972 - accuracy: 0.9014 - iou_metric: 0.0156 - val_loss: 0.4823 - val_accuracy: 0.9493 - val_iou_metric: 0.0472 - lr: 5.0000e-05
# Epoch 8/50
# 230/230 [==============================] - ETA: 0s - loss: 0.4942 - accuracy: 0.9156 - iou_metric: 0.0266
# Epoch 8: val_iou_metric improved from 0.04724 to 0.10133, saving model to fcn32-3d.hdf5
# 230/230 [==============================] - 21s 92ms/step - loss: 0.4942 - accuracy: 0.9156 - iou_metric: 0.0266 - val_loss: 0.4728 - val_accuracy: 0.9607 - val_iou_metric: 0.1013 - lr: 5.0000e-05
# Epoch 9/50
# 230/230 [==============================] - ETA: 0s - loss: 0.4915 - accuracy: 0.9114 - iou_metric: 0.0300
# Epoch 9: val_iou_metric did not improve from 0.10133
# 230/230 [==============================] - 18s 79ms/step - loss: 0.4915 - accuracy: 0.9114 - iou_metric: 0.0300 - val_loss: 0.4972 - val_accuracy: 0.9896 - val_iou_metric: 7.5112e-10 - lr: 5.0000e-05
# Epoch 10/50
# 230/230 [==============================] - ETA: 0s - loss: 0.4971 - accuracy: 0.9078 - iou_metric: 0.0258
# Epoch 10: val_iou_metric did not improve from 0.10133
# 230/230 [==============================] - 19s 81ms/step - loss: 0.4971 - accuracy: 0.9078 - iou_metric: 0.0258 - val_loss: 0.4952 - val_accuracy: 0.7713 - val_iou_metric: 0.0322 - lr: 5.0000e-05
# Epoch 11/50
# 230/230 [==============================] - ETA: 0s - loss: 0.4824 - accuracy: 0.9184 - iou_metric: 0.0472
# Epoch 11: val_iou_metric improved from 0.10133 to 0.11020, saving model to fcn32-3d.hdf5
# 230/230 [==============================] - 20s 89ms/step - loss: 0.4824 - accuracy: 0.9184 - iou_metric: 0.0472 - val_loss: 0.4396 - val_accuracy: 0.9286 - val_iou_metric: 0.1102 - lr: 5.0000e-05
# Epoch 12/50
# 230/230 [==============================] - ETA: 0s - loss: 0.4653 - accuracy: 0.9577 - iou_metric: 0.0759
# Epoch 12: val_iou_metric improved from 0.11020 to 0.22343, saving model to fcn32-3d.hdf5
# 230/230 [==============================] - 22s 95ms/step - loss: 0.4653 - accuracy: 0.9577 - iou_metric: 0.0759 - val_loss: 0.3603 - val_accuracy: 0.9799 - val_iou_metric: 0.2234 - lr: 5.0000e-05
# Epoch 13/50
# 230/230 [==============================] - ETA: 0s - loss: 0.4224 - accuracy: 0.9791 - iou_metric: 0.1367
# Epoch 13: val_iou_metric improved from 0.22343 to 0.22595, saving model to fcn32-3d.hdf5
# 230/230 [==============================] - 21s 92ms/step - loss: 0.4224 - accuracy: 0.9791 - iou_metric: 0.1367 - val_loss: 0.3577 - val_accuracy: 0.9854 - val_iou_metric: 0.2259 - lr: 5.0000e-05
# Epoch 14/50
# 230/230 [==============================] - ETA: 0s - loss: 0.4247 - accuracy: 0.9709 - iou_metric: 0.1448
# Epoch 14: val_iou_metric improved from 0.22595 to 0.23801, saving model to fcn32-3d.hdf5
# 230/230 [==============================] - 21s 92ms/step - loss: 0.4247 - accuracy: 0.9709 - iou_metric: 0.1448 - val_loss: 0.3451 - val_accuracy: 0.9777 - val_iou_metric: 0.2380 - lr: 5.0000e-05
# Epoch 15/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3854 - accuracy: 0.9853 - iou_metric: 0.1923
# Epoch 15: val_iou_metric improved from 0.23801 to 0.30364, saving model to fcn32-3d.hdf5
# 230/230 [==============================] - 21s 94ms/step - loss: 0.3854 - accuracy: 0.9853 - iou_metric: 0.1923 - val_loss: 0.3260 - val_accuracy: 0.9897 - val_iou_metric: 0.3036 - lr: 5.0000e-05
# Epoch 16/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3634 - accuracy: 0.9877 - iou_metric: 0.2237
# Epoch 16: val_iou_metric improved from 0.30364 to 0.30681, saving model to fcn32-3d.hdf5
# 230/230 [==============================] - 21s 91ms/step - loss: 0.3634 - accuracy: 0.9877 - iou_metric: 0.2237 - val_loss: 0.3224 - val_accuracy: 0.9896 - val_iou_metric: 0.3068 - lr: 5.0000e-05
# Epoch 17/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3584 - accuracy: 0.9876 - iou_metric: 0.2325
# Epoch 17: val_iou_metric did not improve from 0.30681
# 230/230 [==============================] - 18s 78ms/step - loss: 0.3584 - accuracy: 0.9876 - iou_metric: 0.2325 - val_loss: 0.3396 - val_accuracy: 0.9724 - val_iou_metric: 0.2307 - lr: 5.0000e-05
# Epoch 18/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3535 - accuracy: 0.9878 - iou_metric: 0.2347
# Epoch 18: val_iou_metric did not improve from 0.30681
# 230/230 [==============================] - 18s 78ms/step - loss: 0.3535 - accuracy: 0.9878 - iou_metric: 0.2347 - val_loss: 0.3079 - val_accuracy: 0.9805 - val_iou_metric: 0.2879 - lr: 5.0000e-05
# Epoch 19/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3406 - accuracy: 0.9890 - iou_metric: 0.2545
# Epoch 19: val_iou_metric improved from 0.30681 to 0.34592, saving model to fcn32-3d.hdf5
# 230/230 [==============================] - 21s 91ms/step - loss: 0.3406 - accuracy: 0.9890 - iou_metric: 0.2545 - val_loss: 0.2959 - val_accuracy: 0.9886 - val_iou_metric: 0.3459 - lr: 5.0000e-05
# Epoch 20/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3388 - accuracy: 0.9883 - iou_metric: 0.2576
# Epoch 20: val_iou_metric did not improve from 0.34592
# 230/230 [==============================] - 18s 77ms/step - loss: 0.3388 - accuracy: 0.9883 - iou_metric: 0.2576 - val_loss: 0.2881 - val_accuracy: 0.9851 - val_iou_metric: 0.3210 - lr: 5.0000e-05
# Epoch 21/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3273 - accuracy: 0.9898 - iou_metric: 0.2751
# Epoch 21: val_iou_metric did not improve from 0.34592
# 230/230 [==============================] - 18s 78ms/step - loss: 0.3273 - accuracy: 0.9898 - iou_metric: 0.2751 - val_loss: 0.2932 - val_accuracy: 0.9848 - val_iou_metric: 0.3099 - lr: 5.0000e-05
# Epoch 22/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3309 - accuracy: 0.9893 - iou_metric: 0.2711
# Epoch 22: val_iou_metric did not improve from 0.34592
# 230/230 [==============================] - 19s 82ms/step - loss: 0.3309 - accuracy: 0.9893 - iou_metric: 0.2711 - val_loss: 0.2997 - val_accuracy: 0.9882 - val_iou_metric: 0.3421 - lr: 5.0000e-05
# Epoch 23/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3263 - accuracy: 0.9892 - iou_metric: 0.2761
# Epoch 23: val_iou_metric improved from 0.34592 to 0.36228, saving model to fcn32-3d.hdf5
# 230/230 [==============================] - 21s 92ms/step - loss: 0.3263 - accuracy: 0.9892 - iou_metric: 0.2761 - val_loss: 0.2776 - val_accuracy: 0.9886 - val_iou_metric: 0.3623 - lr: 5.0000e-05
# Epoch 24/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3269 - accuracy: 0.9896 - iou_metric: 0.2766
# Epoch 24: val_iou_metric did not improve from 0.36228
# 230/230 [==============================] - 19s 81ms/step - loss: 0.3269 - accuracy: 0.9896 - iou_metric: 0.2766 - val_loss: 0.3003 - val_accuracy: 0.9903 - val_iou_metric: 0.3424 - lr: 5.0000e-05
# Epoch 25/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3180 - accuracy: 0.9899 - iou_metric: 0.2853
# Epoch 25: val_iou_metric did not improve from 0.36228
# 230/230 [==============================] - 19s 81ms/step - loss: 0.3180 - accuracy: 0.9899 - iou_metric: 0.2853 - val_loss: 0.2687 - val_accuracy: 0.9878 - val_iou_metric: 0.3612 - lr: 5.0000e-05
# Epoch 26/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3212 - accuracy: 0.9885 - iou_metric: 0.2808
# Epoch 26: val_iou_metric did not improve from 0.36228
# 230/230 [==============================] - 18s 80ms/step - loss: 0.3212 - accuracy: 0.9885 - iou_metric: 0.2808 - val_loss: 0.2773 - val_accuracy: 0.9858 - val_iou_metric: 0.3564 - lr: 5.0000e-05
# Epoch 27/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3147 - accuracy: 0.9893 - iou_metric: 0.2912
# Epoch 27: val_iou_metric did not improve from 0.36228
# 230/230 [==============================] - 18s 77ms/step - loss: 0.3147 - accuracy: 0.9893 - iou_metric: 0.2912 - val_loss: 0.2780 - val_accuracy: 0.9903 - val_iou_metric: 0.3541 - lr: 5.0000e-05
# Epoch 28/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3132 - accuracy: 0.9903 - iou_metric: 0.2959
# Epoch 28: val_iou_metric did not improve from 0.36228
# 230/230 [==============================] - 18s 79ms/step - loss: 0.3132 - accuracy: 0.9903 - iou_metric: 0.2959 - val_loss: 0.2769 - val_accuracy: 0.9856 - val_iou_metric: 0.3521 - lr: 5.0000e-05
# Epoch 29/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3121 - accuracy: 0.9899 - iou_metric: 0.2968
# Epoch 29: val_iou_metric did not improve from 0.36228
# 230/230 [==============================] - 19s 81ms/step - loss: 0.3121 - accuracy: 0.9899 - iou_metric: 0.2968 - val_loss: 0.2656 - val_accuracy: 0.9869 - val_iou_metric: 0.3603 - lr: 5.0000e-05
# Epoch 30/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3088 - accuracy: 0.9897 - iou_metric: 0.2994
# Epoch 30: val_iou_metric improved from 0.36228 to 0.37057, saving model to fcn32-3d.hdf5
# 230/230 [==============================] - 21s 91ms/step - loss: 0.3088 - accuracy: 0.9897 - iou_metric: 0.2994 - val_loss: 0.2652 - val_accuracy: 0.9866 - val_iou_metric: 0.3706 - lr: 5.0000e-05
# Epoch 31/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3024 - accuracy: 0.9903 - iou_metric: 0.3130
# Epoch 31: val_iou_metric improved from 0.37057 to 0.37297, saving model to fcn32-3d.hdf5
# 230/230 [==============================] - 21s 93ms/step - loss: 0.3024 - accuracy: 0.9903 - iou_metric: 0.3130 - val_loss: 0.2666 - val_accuracy: 0.9896 - val_iou_metric: 0.3730 - lr: 5.0000e-05
# Epoch 32/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3029 - accuracy: 0.9907 - iou_metric: 0.3104
# Epoch 32: val_iou_metric did not improve from 0.37297
# 230/230 [==============================] - 18s 80ms/step - loss: 0.3029 - accuracy: 0.9907 - iou_metric: 0.3104 - val_loss: 0.2640 - val_accuracy: 0.9872 - val_iou_metric: 0.3692 - lr: 5.0000e-05
# Epoch 33/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3041 - accuracy: 0.9903 - iou_metric: 0.3054
# Epoch 33: val_iou_metric did not improve from 0.37297
# 230/230 [==============================] - 19s 81ms/step - loss: 0.3041 - accuracy: 0.9903 - iou_metric: 0.3054 - val_loss: 0.2676 - val_accuracy: 0.9884 - val_iou_metric: 0.3643 - lr: 5.0000e-05
# Epoch 34/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2985 - accuracy: 0.9911 - iou_metric: 0.3162
# Epoch 34: val_iou_metric did not improve from 0.37297
# 230/230 [==============================] - 19s 81ms/step - loss: 0.2985 - accuracy: 0.9911 - iou_metric: 0.3162 - val_loss: 0.2658 - val_accuracy: 0.9873 - val_iou_metric: 0.3590 - lr: 5.0000e-05
# Epoch 35/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2970 - accuracy: 0.9901 - iou_metric: 0.3138
# Epoch 35: val_iou_metric improved from 0.37297 to 0.38600, saving model to fcn32-3d.hdf5
# 230/230 [==============================] - 21s 92ms/step - loss: 0.2970 - accuracy: 0.9901 - iou_metric: 0.3138 - val_loss: 0.2527 - val_accuracy: 0.9880 - val_iou_metric: 0.3860 - lr: 5.0000e-05
# Epoch 36/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2950 - accuracy: 0.9906 - iou_metric: 0.3236
# Epoch 36: val_iou_metric did not improve from 0.38600
# 230/230 [==============================] - 18s 79ms/step - loss: 0.2950 - accuracy: 0.9906 - iou_metric: 0.3236 - val_loss: 0.2532 - val_accuracy: 0.9875 - val_iou_metric: 0.3819 - lr: 5.0000e-05
# Epoch 37/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2972 - accuracy: 0.9905 - iou_metric: 0.3229
# Epoch 37: val_iou_metric improved from 0.38600 to 0.38809, saving model to fcn32-3d.hdf5
# 230/230 [==============================] - 22s 94ms/step - loss: 0.2972 - accuracy: 0.9905 - iou_metric: 0.3229 - val_loss: 0.2518 - val_accuracy: 0.9885 - val_iou_metric: 0.3881 - lr: 5.0000e-05
# Epoch 38/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2930 - accuracy: 0.9911 - iou_metric: 0.3269
# Epoch 38: val_iou_metric improved from 0.38809 to 0.38856, saving model to fcn32-3d.hdf5
# 230/230 [==============================] - 21s 91ms/step - loss: 0.2930 - accuracy: 0.9911 - iou_metric: 0.3269 - val_loss: 0.2542 - val_accuracy: 0.9889 - val_iou_metric: 0.3886 - lr: 5.0000e-05
# Epoch 39/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2887 - accuracy: 0.9909 - iou_metric: 0.3294
# Epoch 39: val_iou_metric did not improve from 0.38856
# 230/230 [==============================] - 18s 79ms/step - loss: 0.2887 - accuracy: 0.9909 - iou_metric: 0.3294 - val_loss: 0.2578 - val_accuracy: 0.9895 - val_iou_metric: 0.3846 - lr: 5.0000e-05
# Epoch 40/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2922 - accuracy: 0.9904 - iou_metric: 0.3239
# Epoch 40: val_iou_metric did not improve from 0.38856
# 230/230 [==============================] - 18s 80ms/step - loss: 0.2922 - accuracy: 0.9904 - iou_metric: 0.3239 - val_loss: 0.2655 - val_accuracy: 0.9889 - val_iou_metric: 0.3725 - lr: 5.0000e-05
# Epoch 41/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2920 - accuracy: 0.9907 - iou_metric: 0.3236
# Epoch 41: val_iou_metric improved from 0.38856 to 0.39690, saving model to fcn32-3d.hdf5
# 230/230 [==============================] - 20s 89ms/step - loss: 0.2920 - accuracy: 0.9907 - iou_metric: 0.3236 - val_loss: 0.2542 - val_accuracy: 0.9887 - val_iou_metric: 0.3969 - lr: 5.0000e-05
# Epoch 42/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2920 - accuracy: 0.9899 - iou_metric: 0.3217
# Epoch 42: val_iou_metric did not improve from 0.39690
# 230/230 [==============================] - 18s 77ms/step - loss: 0.2920 - accuracy: 0.9899 - iou_metric: 0.3217 - val_loss: 0.2572 - val_accuracy: 0.9876 - val_iou_metric: 0.3848 - lr: 5.0000e-05
# Epoch 43/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2874 - accuracy: 0.9914 - iou_metric: 0.3327
# Epoch 43: val_iou_metric did not improve from 0.39690
# 230/230 [==============================] - 18s 80ms/step - loss: 0.2874 - accuracy: 0.9914 - iou_metric: 0.3327 - val_loss: 0.2602 - val_accuracy: 0.9900 - val_iou_metric: 0.3880 - lr: 5.0000e-05
# Epoch 44/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2918 - accuracy: 0.9913 - iou_metric: 0.3239
# Epoch 44: val_iou_metric improved from 0.39690 to 0.39944, saving model to fcn32-3d.hdf5
# 230/230 [==============================] - 21s 93ms/step - loss: 0.2918 - accuracy: 0.9913 - iou_metric: 0.3239 - val_loss: 0.2488 - val_accuracy: 0.9883 - val_iou_metric: 0.3994 - lr: 5.0000e-05
# Epoch 45/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2852 - accuracy: 0.9914 - iou_metric: 0.3350
# Epoch 45: val_iou_metric improved from 0.39944 to 0.40238, saving model to fcn32-3d.hdf5
# 230/230 [==============================] - 20s 89ms/step - loss: 0.2852 - accuracy: 0.9914 - iou_metric: 0.3350 - val_loss: 0.2430 - val_accuracy: 0.9885 - val_iou_metric: 0.4024 - lr: 5.0000e-05
# Epoch 46/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2790 - accuracy: 0.9912 - iou_metric: 0.3456
# Epoch 46: val_iou_metric did not improve from 0.40238
# 230/230 [==============================] - 18s 77ms/step - loss: 0.2790 - accuracy: 0.9912 - iou_metric: 0.3456 - val_loss: 0.2510 - val_accuracy: 0.9889 - val_iou_metric: 0.3997 - lr: 5.0000e-05
# Epoch 47/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2821 - accuracy: 0.9916 - iou_metric: 0.3390
# Epoch 47: val_iou_metric did not improve from 0.40238
# 230/230 [==============================] - 18s 80ms/step - loss: 0.2821 - accuracy: 0.9916 - iou_metric: 0.3390 - val_loss: 0.2468 - val_accuracy: 0.9869 - val_iou_metric: 0.3905 - lr: 5.0000e-05
# Epoch 48/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2780 - accuracy: 0.9912 - iou_metric: 0.3465
# Epoch 48: val_iou_metric improved from 0.40238 to 0.40376, saving model to fcn32-3d.hdf5
# 230/230 [==============================] - 20s 85ms/step - loss: 0.2780 - accuracy: 0.9912 - iou_metric: 0.3465 - val_loss: 0.2448 - val_accuracy: 0.9889 - val_iou_metric: 0.4038 - lr: 5.0000e-05
# Epoch 49/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2778 - accuracy: 0.9913 - iou_metric: 0.3465
# Epoch 49: val_iou_metric did not improve from 0.40376
# 230/230 [==============================] - 18s 80ms/step - loss: 0.2778 - accuracy: 0.9913 - iou_metric: 0.3465 - val_loss: 0.2583 - val_accuracy: 0.9883 - val_iou_metric: 0.3834 - lr: 5.0000e-05
# Epoch 50/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2820 - accuracy: 0.9913 - iou_metric: 0.3402
# Epoch 50: val_iou_metric did not improve from 0.40376
# 230/230 [==============================] - 18s 78ms/step - loss: 0.2820 - accuracy: 0.9913 - iou_metric: 0.3402 - val_loss: 0.2435 - val_accuracy: 0.9883 - val_iou_metric: 0.4014 - lr: 5.0000e-05

# %%
# Save model history
np.save('fcn32-3d-history.npy', F.history.history)

# %% [markdown]
# ## ResUNet

# %%
R = res_unet(512, [64, 128, 256, 512], 3, 3, 1)
save_model_resunet = ModelCheckpoint('resunet-3d.hdf5', monitor='val_iou_metric',verbose=1, save_best_only=True, save_weights_only=True, mode='max')
train = trainGenerator(1, t_images, t_masks, data_gen_args, save_to_dir=None)
R.fit(train, steps_per_epoch = 230, epochs=50, validation_data = validation_Nepal_landslide_dataset, callbacks=[save_model_resunet, reduce_lr])
# Out:
# Epoch 1/50
# 230/230 [==============================] - ETA: 0s - loss: 0.5412 - accuracy: 0.9016 - iou_metric: 0.0813
# Epoch 1: val_iou_metric improved from -inf to 0.29779, saving model to resunet-3d.hdf5
# 230/230 [==============================] - 31s 95ms/step - loss: 0.5412 - accuracy: 0.9016 - iou_metric: 0.0813 - val_loss: 0.3103 - val_accuracy: 0.9860 - val_iou_metric: 0.2978 - lr: 1.0000e-04
# Epoch 2/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3879 - accuracy: 0.9684 - iou_metric: 0.1944
# Epoch 2: val_iou_metric did not improve from 0.29779
# 230/230 [==============================] - 21s 93ms/step - loss: 0.3879 - accuracy: 0.9684 - iou_metric: 0.1944 - val_loss: 0.3661 - val_accuracy: 0.9519 - val_iou_metric: 0.1912 - lr: 1.0000e-04
# Epoch 3/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3678 - accuracy: 0.9683 - iou_metric: 0.2211
# Epoch 3: val_iou_metric improved from 0.29779 to 0.33650, saving model to resunet-3d.hdf5
# 230/230 [==============================] - 22s 94ms/step - loss: 0.3678 - accuracy: 0.9683 - iou_metric: 0.2211 - val_loss: 0.2807 - val_accuracy: 0.9827 - val_iou_metric: 0.3365 - lr: 1.0000e-04
# Epoch 4/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3398 - accuracy: 0.9806 - iou_metric: 0.2538
# Epoch 4: val_iou_metric improved from 0.33650 to 0.34243, saving model to resunet-3d.hdf5
# 230/230 [==============================] - 21s 93ms/step - loss: 0.3398 - accuracy: 0.9806 - iou_metric: 0.2538 - val_loss: 0.2837 - val_accuracy: 0.9915 - val_iou_metric: 0.3424 - lr: 1.0000e-04
# Epoch 5/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3346 - accuracy: 0.9802 - iou_metric: 0.2635
# Epoch 5: val_iou_metric improved from 0.34243 to 0.37252, saving model to resunet-3d.hdf5
# 230/230 [==============================] - 22s 96ms/step - loss: 0.3346 - accuracy: 0.9802 - iou_metric: 0.2635 - val_loss: 0.2556 - val_accuracy: 0.9855 - val_iou_metric: 0.3725 - lr: 1.0000e-04
# Epoch 6/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3308 - accuracy: 0.9837 - iou_metric: 0.2659
# Epoch 6: val_iou_metric did not improve from 0.37252
# 230/230 [==============================] - 22s 94ms/step - loss: 0.3308 - accuracy: 0.9837 - iou_metric: 0.2659 - val_loss: 0.2621 - val_accuracy: 0.9817 - val_iou_metric: 0.3538 - lr: 1.0000e-04
# Epoch 7/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3225 - accuracy: 0.9782 - iou_metric: 0.2818
# Epoch 7: val_iou_metric did not improve from 0.37252
# 230/230 [==============================] - 21s 93ms/step - loss: 0.3225 - accuracy: 0.9782 - iou_metric: 0.2818 - val_loss: 0.2915 - val_accuracy: 0.9915 - val_iou_metric: 0.3398 - lr: 1.0000e-04
# Epoch 8/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3213 - accuracy: 0.9851 - iou_metric: 0.2848
# Epoch 8: val_iou_metric improved from 0.37252 to 0.40469, saving model to resunet-3d.hdf5
# 230/230 [==============================] - 22s 94ms/step - loss: 0.3213 - accuracy: 0.9851 - iou_metric: 0.2848 - val_loss: 0.2429 - val_accuracy: 0.9900 - val_iou_metric: 0.4047 - lr: 1.0000e-04
# Epoch 9/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3330 - accuracy: 0.9827 - iou_metric: 0.2608
# Epoch 9: val_iou_metric did not improve from 0.40469
# 230/230 [==============================] - 21s 93ms/step - loss: 0.3330 - accuracy: 0.9827 - iou_metric: 0.2608 - val_loss: 0.2466 - val_accuracy: 0.9878 - val_iou_metric: 0.3927 - lr: 1.0000e-04
# Epoch 10/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3185 - accuracy: 0.9857 - iou_metric: 0.2825
# Epoch 10: val_iou_metric did not improve from 0.40469
# 230/230 [==============================] - 21s 91ms/step - loss: 0.3185 - accuracy: 0.9857 - iou_metric: 0.2825 - val_loss: 0.2510 - val_accuracy: 0.9912 - val_iou_metric: 0.3886 - lr: 1.0000e-04
# Epoch 11/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3048 - accuracy: 0.9871 - iou_metric: 0.3042
# Epoch 11: val_iou_metric did not improve from 0.40469
# 230/230 [==============================] - 21s 91ms/step - loss: 0.3048 - accuracy: 0.9871 - iou_metric: 0.3042 - val_loss: 0.2449 - val_accuracy: 0.9840 - val_iou_metric: 0.3891 - lr: 1.0000e-04
# Epoch 12/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3125 - accuracy: 0.9864 - iou_metric: 0.2945
# Epoch 12: val_iou_metric did not improve from 0.40469
# 230/230 [==============================] - 21s 93ms/step - loss: 0.3125 - accuracy: 0.9864 - iou_metric: 0.2945 - val_loss: 0.2482 - val_accuracy: 0.9850 - val_iou_metric: 0.3842 - lr: 1.0000e-04
# Epoch 13/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3022 - accuracy: 0.9869 - iou_metric: 0.3051
# Epoch 13: val_iou_metric did not improve from 0.40469
# 230/230 [==============================] - 21s 92ms/step - loss: 0.3022 - accuracy: 0.9869 - iou_metric: 0.3051 - val_loss: 0.2399 - val_accuracy: 0.9911 - val_iou_metric: 0.4035 - lr: 1.0000e-04
# Epoch 14/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3052 - accuracy: 0.9860 - iou_metric: 0.3066
# Epoch 14: val_iou_metric did not improve from 0.40469
# 230/230 [==============================] - 21s 93ms/step - loss: 0.3052 - accuracy: 0.9860 - iou_metric: 0.3066 - val_loss: 0.2513 - val_accuracy: 0.9906 - val_iou_metric: 0.3893 - lr: 1.0000e-04
# Epoch 15/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3072 - accuracy: 0.9857 - iou_metric: 0.3003
# Epoch 15: val_iou_metric improved from 0.40469 to 0.45165, saving model to resunet-3d.hdf5
# 230/230 [==============================] - 22s 94ms/step - loss: 0.3072 - accuracy: 0.9857 - iou_metric: 0.3003 - val_loss: 0.2130 - val_accuracy: 0.9907 - val_iou_metric: 0.4517 - lr: 1.0000e-04
# Epoch 16/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3027 - accuracy: 0.9874 - iou_metric: 0.3068
# Epoch 16: val_iou_metric did not improve from 0.45165
# 230/230 [==============================] - 21s 92ms/step - loss: 0.3027 - accuracy: 0.9874 - iou_metric: 0.3068 - val_loss: 0.2366 - val_accuracy: 0.9915 - val_iou_metric: 0.4132 - lr: 1.0000e-04
# Epoch 17/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3136 - accuracy: 0.9858 - iou_metric: 0.2909
# Epoch 17: val_iou_metric did not improve from 0.45165
# 230/230 [==============================] - 21s 92ms/step - loss: 0.3136 - accuracy: 0.9858 - iou_metric: 0.2909 - val_loss: 0.2361 - val_accuracy: 0.9856 - val_iou_metric: 0.4032 - lr: 1.0000e-04
# Epoch 18/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2984 - accuracy: 0.9869 - iou_metric: 0.3146
# Epoch 18: val_iou_metric did not improve from 0.45165
# 230/230 [==============================] - 21s 92ms/step - loss: 0.2984 - accuracy: 0.9869 - iou_metric: 0.3146 - val_loss: 0.2295 - val_accuracy: 0.9882 - val_iou_metric: 0.4168 - lr: 1.0000e-04
# Epoch 19/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2914 - accuracy: 0.9879 - iou_metric: 0.3232
# Epoch 19: val_iou_metric did not improve from 0.45165
# 230/230 [==============================] - 21s 93ms/step - loss: 0.2914 - accuracy: 0.9879 - iou_metric: 0.3232 - val_loss: 0.2394 - val_accuracy: 0.9868 - val_iou_metric: 0.3994 - lr: 1.0000e-04
# Epoch 20/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2975 - accuracy: 0.9879 - iou_metric: 0.3138
# Epoch 20: val_iou_metric did not improve from 0.45165
# 230/230 [==============================] - 21s 92ms/step - loss: 0.2975 - accuracy: 0.9879 - iou_metric: 0.3138 - val_loss: 0.2452 - val_accuracy: 0.9891 - val_iou_metric: 0.3908 - lr: 1.0000e-04
# Epoch 21/50
# 230/230 [==============================] - ETA: 0s - loss: 0.3038 - accuracy: 0.9858 - iou_metric: 0.3062
# Epoch 21: val_iou_metric improved from 0.45165 to 0.45366, saving model to resunet-3d.hdf5
# 230/230 [==============================] - 21s 91ms/step - loss: 0.3038 - accuracy: 0.9858 - iou_metric: 0.3062 - val_loss: 0.2142 - val_accuracy: 0.9916 - val_iou_metric: 0.4537 - lr: 1.0000e-04
# Epoch 22/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2963 - accuracy: 0.9850 - iou_metric: 0.3195
# Epoch 22: val_iou_metric did not improve from 0.45366
# 230/230 [==============================] - 21s 93ms/step - loss: 0.2963 - accuracy: 0.9850 - iou_metric: 0.3195 - val_loss: 0.2614 - val_accuracy: 0.9879 - val_iou_metric: 0.3607 - lr: 1.0000e-04
# Epoch 23/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2987 - accuracy: 0.9880 - iou_metric: 0.3160
# Epoch 23: val_iou_metric did not improve from 0.45366
# 230/230 [==============================] - 21s 92ms/step - loss: 0.2987 - accuracy: 0.9880 - iou_metric: 0.3160 - val_loss: 0.2149 - val_accuracy: 0.9912 - val_iou_metric: 0.4482 - lr: 1.0000e-04
# Epoch 24/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2867 - accuracy: 0.9886 - iou_metric: 0.3299
# Epoch 24: val_iou_metric did not improve from 0.45366
# 230/230 [==============================] - 21s 94ms/step - loss: 0.2867 - accuracy: 0.9886 - iou_metric: 0.3299 - val_loss: 0.2170 - val_accuracy: 0.9914 - val_iou_metric: 0.4432 - lr: 1.0000e-04
# Epoch 25/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2765 - accuracy: 0.9902 - iou_metric: 0.3459
# Epoch 25: val_iou_metric did not improve from 0.45366
# 230/230 [==============================] - 21s 90ms/step - loss: 0.2765 - accuracy: 0.9902 - iou_metric: 0.3459 - val_loss: 0.2210 - val_accuracy: 0.9918 - val_iou_metric: 0.4411 - lr: 1.0000e-04
# Epoch 26/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2838 - accuracy: 0.9902 - iou_metric: 0.3402
# Epoch 26: val_iou_metric did not improve from 0.45366
# 230/230 [==============================] - 21s 93ms/step - loss: 0.2838 - accuracy: 0.9902 - iou_metric: 0.3402 - val_loss: 0.2228 - val_accuracy: 0.9878 - val_iou_metric: 0.4231 - lr: 1.0000e-04
# Epoch 27/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2812 - accuracy: 0.9878 - iou_metric: 0.3367
# Epoch 27: val_iou_metric did not improve from 0.45366
# 230/230 [==============================] - 21s 93ms/step - loss: 0.2812 - accuracy: 0.9878 - iou_metric: 0.3367 - val_loss: 0.2255 - val_accuracy: 0.9916 - val_iou_metric: 0.4389 - lr: 1.0000e-04
# Epoch 28/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2788 - accuracy: 0.9894 - iou_metric: 0.3458
# Epoch 28: val_iou_metric did not improve from 0.45366
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 230/230 [==============================] - 21s 92ms/step - loss: 0.2788 - accuracy: 0.9894 - iou_metric: 0.3458 - val_loss: 0.2189 - val_accuracy: 0.9905 - val_iou_metric: 0.4394 - lr: 1.0000e-04
# Epoch 29/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2703 - accuracy: 0.9897 - iou_metric: 0.3565
# Epoch 29: val_iou_metric improved from 0.45366 to 0.46211, saving model to resunet-3d.hdf5
# 230/230 [==============================] - 22s 94ms/step - loss: 0.2703 - accuracy: 0.9897 - iou_metric: 0.3565 - val_loss: 0.2056 - val_accuracy: 0.9905 - val_iou_metric: 0.4621 - lr: 5.0000e-05
# Epoch 30/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2580 - accuracy: 0.9904 - iou_metric: 0.3785
# Epoch 30: val_iou_metric did not improve from 0.46211
# 230/230 [==============================] - 21s 92ms/step - loss: 0.2580 - accuracy: 0.9904 - iou_metric: 0.3785 - val_loss: 0.2078 - val_accuracy: 0.9904 - val_iou_metric: 0.4572 - lr: 5.0000e-05
# Epoch 31/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2614 - accuracy: 0.9913 - iou_metric: 0.3746
# Epoch 31: val_iou_metric improved from 0.46211 to 0.49137, saving model to resunet-3d.hdf5
# 230/230 [==============================] - 21s 93ms/step - loss: 0.2614 - accuracy: 0.9913 - iou_metric: 0.3746 - val_loss: 0.1940 - val_accuracy: 0.9925 - val_iou_metric: 0.4914 - lr: 5.0000e-05
# Epoch 32/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2633 - accuracy: 0.9909 - iou_metric: 0.3685
# Epoch 32: val_iou_metric did not improve from 0.49137
# 230/230 [==============================] - 21s 91ms/step - loss: 0.2633 - accuracy: 0.9909 - iou_metric: 0.3685 - val_loss: 0.2122 - val_accuracy: 0.9909 - val_iou_metric: 0.4514 - lr: 5.0000e-05
# Epoch 33/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2560 - accuracy: 0.9906 - iou_metric: 0.3822
# Epoch 33: val_iou_metric improved from 0.49137 to 0.49729, saving model to resunet-3d.hdf5
# 230/230 [==============================] - 21s 93ms/step - loss: 0.2560 - accuracy: 0.9906 - iou_metric: 0.3822 - val_loss: 0.1876 - val_accuracy: 0.9925 - val_iou_metric: 0.4973 - lr: 5.0000e-05
# Epoch 34/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2557 - accuracy: 0.9899 - iou_metric: 0.3790
# Epoch 34: val_iou_metric did not improve from 0.49729
# 230/230 [==============================] - 21s 93ms/step - loss: 0.2557 - accuracy: 0.9899 - iou_metric: 0.3790 - val_loss: 0.2189 - val_accuracy: 0.9882 - val_iou_metric: 0.4276 - lr: 5.0000e-05
# Epoch 35/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2555 - accuracy: 0.9911 - iou_metric: 0.3811
# Epoch 35: val_iou_metric did not improve from 0.49729
# 230/230 [==============================] - 21s 92ms/step - loss: 0.2555 - accuracy: 0.9911 - iou_metric: 0.3811 - val_loss: 0.1911 - val_accuracy: 0.9917 - val_iou_metric: 0.4903 - lr: 5.0000e-05
# Epoch 36/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2575 - accuracy: 0.9904 - iou_metric: 0.3788
# Epoch 36: val_iou_metric did not improve from 0.49729
# 230/230 [==============================] - 21s 91ms/step - loss: 0.2575 - accuracy: 0.9904 - iou_metric: 0.3788 - val_loss: 0.2025 - val_accuracy: 0.9897 - val_iou_metric: 0.4651 - lr: 5.0000e-05
# Epoch 37/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2558 - accuracy: 0.9903 - iou_metric: 0.3777
# Epoch 37: val_iou_metric did not improve from 0.49729
# 230/230 [==============================] - 21s 92ms/step - loss: 0.2558 - accuracy: 0.9903 - iou_metric: 0.3777 - val_loss: 0.1976 - val_accuracy: 0.9911 - val_iou_metric: 0.4765 - lr: 5.0000e-05
# Epoch 38/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2570 - accuracy: 0.9911 - iou_metric: 0.3779
# Epoch 38: val_iou_metric did not improve from 0.49729
# 230/230 [==============================] - 21s 92ms/step - loss: 0.2570 - accuracy: 0.9911 - iou_metric: 0.3779 - val_loss: 0.1948 - val_accuracy: 0.9927 - val_iou_metric: 0.4905 - lr: 5.0000e-05
# Epoch 39/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2580 - accuracy: 0.9915 - iou_metric: 0.3808
# Epoch 39: val_iou_metric did not improve from 0.49729
# 230/230 [==============================] - 21s 92ms/step - loss: 0.2580 - accuracy: 0.9915 - iou_metric: 0.3808 - val_loss: 0.2029 - val_accuracy: 0.9923 - val_iou_metric: 0.4702 - lr: 5.0000e-05
# Epoch 40/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2481 - accuracy: 0.9912 - iou_metric: 0.3930
# Epoch 40: val_iou_metric improved from 0.49729 to 0.49874, saving model to resunet-3d.hdf5
# 230/230 [==============================] - 21s 93ms/step - loss: 0.2481 - accuracy: 0.9912 - iou_metric: 0.3930 - val_loss: 0.1893 - val_accuracy: 0.9927 - val_iou_metric: 0.4987 - lr: 5.0000e-05
# Epoch 41/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2498 - accuracy: 0.9915 - iou_metric: 0.3947
# Epoch 41: val_iou_metric improved from 0.49874 to 0.50701, saving model to resunet-3d.hdf5
# 230/230 [==============================] - 21s 92ms/step - loss: 0.2498 - accuracy: 0.9915 - iou_metric: 0.3947 - val_loss: 0.1840 - val_accuracy: 0.9925 - val_iou_metric: 0.5070 - lr: 5.0000e-05
# Epoch 42/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2536 - accuracy: 0.9913 - iou_metric: 0.3865
# Epoch 42: val_iou_metric improved from 0.50701 to 0.51886, saving model to resunet-3d.hdf5
# 230/230 [==============================] - 21s 93ms/step - loss: 0.2536 - accuracy: 0.9913 - iou_metric: 0.3865 - val_loss: 0.1801 - val_accuracy: 0.9932 - val_iou_metric: 0.5189 - lr: 5.0000e-05
# Epoch 43/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2490 - accuracy: 0.9908 - iou_metric: 0.3918
# Epoch 43: val_iou_metric did not improve from 0.51886
# 230/230 [==============================] - 21s 91ms/step - loss: 0.2490 - accuracy: 0.9908 - iou_metric: 0.3918 - val_loss: 0.1927 - val_accuracy: 0.9927 - val_iou_metric: 0.5017 - lr: 5.0000e-05
# Epoch 44/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2520 - accuracy: 0.9915 - iou_metric: 0.3883
# Epoch 44: val_iou_metric improved from 0.51886 to 0.52490, saving model to resunet-3d.hdf5
# 230/230 [==============================] - 21s 93ms/step - loss: 0.2520 - accuracy: 0.9915 - iou_metric: 0.3883 - val_loss: 0.1765 - val_accuracy: 0.9927 - val_iou_metric: 0.5249 - lr: 5.0000e-05
# Epoch 45/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2498 - accuracy: 0.9917 - iou_metric: 0.3919
# Epoch 45: val_iou_metric did not improve from 0.52490
# 230/230 [==============================] - 21s 92ms/step - loss: 0.2498 - accuracy: 0.9917 - iou_metric: 0.3919 - val_loss: 0.1885 - val_accuracy: 0.9914 - val_iou_metric: 0.4915 - lr: 5.0000e-05
# Epoch 46/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2467 - accuracy: 0.9910 - iou_metric: 0.3972
# Epoch 46: val_iou_metric did not improve from 0.52490
# 230/230 [==============================] - 22s 94ms/step - loss: 0.2467 - accuracy: 0.9910 - iou_metric: 0.3972 - val_loss: 0.1971 - val_accuracy: 0.9911 - val_iou_metric: 0.4789 - lr: 5.0000e-05
# Epoch 47/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2443 - accuracy: 0.9915 - iou_metric: 0.4027
# Epoch 47: val_iou_metric did not improve from 0.52490
# 230/230 [==============================] - 21s 92ms/step - loss: 0.2443 - accuracy: 0.9915 - iou_metric: 0.4027 - val_loss: 0.1853 - val_accuracy: 0.9924 - val_iou_metric: 0.5036 - lr: 5.0000e-05
# Epoch 48/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2411 - accuracy: 0.9916 - iou_metric: 0.4091
# Epoch 48: val_iou_metric did not improve from 0.52490
# 230/230 [==============================] - 21s 91ms/step - loss: 0.2411 - accuracy: 0.9916 - iou_metric: 0.4091 - val_loss: 0.1853 - val_accuracy: 0.9930 - val_iou_metric: 0.5092 - lr: 5.0000e-05
# Epoch 49/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2429 - accuracy: 0.9910 - iou_metric: 0.4014
# Epoch 49: val_iou_metric did not improve from 0.52490
# 230/230 [==============================] - 21s 92ms/step - loss: 0.2429 - accuracy: 0.9910 - iou_metric: 0.4014 - val_loss: 0.1836 - val_accuracy: 0.9924 - val_iou_metric: 0.5054 - lr: 5.0000e-05
# Epoch 50/50
# 230/230 [==============================] - ETA: 0s - loss: 0.2367 - accuracy: 0.9920 - iou_metric: 0.4119
# Epoch 50: val_iou_metric improved from 0.52490 to 0.52664, saving model to resunet-3d.hdf5
# 230/230 [==============================] - 22s 94ms/step - loss: 0.2367 - accuracy: 0.9920 - iou_metric: 0.4119 - val_loss: 0.1756 - val_accuracy: 0.9929 - val_iou_metric: 0.5266 - lr: 5.0000e-05

# %%
# Save model history
np.save('resunet-3d-history.npy',R.history.history)

# %% [markdown]
# # Import Models and Compute Metrics

# %% [markdown]
# ## RGB

# %%
# Load 3-dim models and history stats
attention_unet = load_model(
    'unet-attention-3d.hdf5',
    custom_objects={
        'iou_metric': iou_metric,
        'bce_dice_loss_weighted': bce_dice_loss_weighted
    }
)

unet = load_model(
    'unet-3d.hdf5',
    custom_objects={'iou_metric': iou_metric,
                    'bce_dice_loss_weighted': bce_dice_loss_weighted
                   }
)

unet_history = np.load('unet-3d-history.npy', allow_pickle='TRUE').item()
attention_unet_history = np.load('unet-attention-3d-history.npy', allow_pickle='TRUE').item()

# %%
# Plot accuracy and loss for U-Net

## Accuracy

plt.plot(unet_history['iou_metric'])
plt.plot(unet_history['val_iou_metric'])

plt.ylabel('IoU')
plt.xlabel('Epoch')
plt.legend(['Unet Training IoU', 'Unet Validation IoU'], loc='upper left')
plt.grid(True)
plt.show()


## Loss
plt.plot(unet_history['loss'])
plt.plot(unet_history['val_loss'])
plt.ylabel('Loss', size=12)
plt.xlabel('Epoch', size=12)
plt.legend(['Unet Training Loss', 'Unet Validation Loss'], loc='lower right')

# %%
# Plot accuracy and loss for Attention U-Net

## Accuracy

plt.plot(attention_unet_history['iou_metric'])
plt.plot(attention_unet_history['val_iou_metric'])

plt.ylabel('IoU')
plt.xlabel('Epoch')
plt.legend(['Attention Unet Training IoU', 'Attention Unet Validation IoU'], loc='upper left')
plt.grid(True)
plt.show()


## Loss
plt.plot(attention_unet_history['loss'])
plt.plot(attention_unet_history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Attention Unet Training Loss', 'Attention Unet Validation Loss'], loc='upper right')

# %%
# Scores of each model
unet_score = (score_eval(unet, validation_images, validation_masks))
am_unet_score = (score_eval(attention_unet, validation_images, validation_masks))
# Out:
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 365ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step

# %%
# Precision and recall of each model
unet_precision = (precision_eval(unet, validation_images, validation_masks))
am_unet_precision = (precision_eval(attention_unet, validation_images, validation_masks))

unet_recall = (recall_eval(unet, validation_images, validation_masks))
am_unet_recall = (recall_eval(attention_unet, validation_images, validation_masks))
# Out:
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step

# %%
# F1-scores of each model
unet_f1_score = (f1_score_eval_basic(unet_precision, unet_recall))
am_unet_f1_score = (f1_score_eval_basic(am_unet_precision, am_unet_recall))

# %%
# Print score eval results for each model
print('U-Net accuracy: ', np.mean(unet_score), np.std(unet_score))
print('Attention U-Net accuracy: ', np.mean(am_unet_score), np.std(am_unet_score))
# Out:
# U-Net accuracy:  0.9924019949776786 0.006642707447956307
# Attention U-Net accuracy:  0.9903775896344866 0.0072942557607365574

# %%
# Print precision eval results for each model
print('U-Net precision: ', np.mean(unet_precision), np.std(unet_precision))
print('Attention U-Net precision: ', np.mean(am_unet_precision), np.std(am_unet_precision))
# Out:
# U-Net precision:  0.9934560441379177 0.005924326837873973
# Attention U-Net precision:  0.9887523092162039 0.00888986915949721

# %%
# Print recall eval results for each model
print('U-Net recall: ', np.mean(unet_recall), np.std(unet_recall))
print('Attention U-Net recall: ', np.mean(am_unet_recall), np.std(am_unet_recall))
# Out:
# U-Net recall:  0.9924019949776786 0.006642707447956307
# Attention U-Net recall:  0.9903775896344866 0.0072942557607365574

# %%
# Print f1-score eval results for each model
print('U-Net F1-score: ', np.mean(unet_f1_score))
print('Attention U-Net F1-score: ', np.mean(am_unet_f1_score))
# Out:
# U-Net F1-score:  0.9929287398249043
# Attention U-Net F1-score:  0.9895642820774264
